# %%
import os
import torch
import numpy as np
import csv

class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []
        self.pretrain_vec = [] # should match index order of words in dict.

    def add_word(self, word, vec=None):
        if vec is None:
            if word not in self.word2idx:
                self.idx2word.append(word)
                self.word2idx[word] = len(self.idx2word) - 1
        else:
            if word not in self.word2idx:
                self.pretrain_vec.append(vec)
                self.idx2word.append(word)
                self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self, path, language):
        self.dictionary = Dictionary()
        if language is not None:
            self.pretrained = self.add_pretrained(os.path.join('', 'wiki.' + language + '.vec'))
        #self.trainid, self.trainlab, self.trainidx = self.tokenize_by_user(os.path.join(path, 'train.csv'),True)
        #self.validid, self.validlab, self.valididx = self.tokenize_by_user(os.path.join(path, 'valid.csv'),False)
        #self.testid, self.testlab, self.testidx = self.tokenize_by_user(os.path.join(path, 'test.csv'),False)
        self.X_train, self.y_train = self.tokenize(os.path.join('', 'train.csv'),True)
        #self.X_valid, self.y_valid = self.tokenize(os.path.join(path, 'valid.csv'),False)
        self.X_test, self.y_test = self.tokenize(os.path.join('', 'test.csv'),False)

    def add_pretrained(self, path):
        assert os.path.exists(path)

        # Add words with pretrained vectors to the dictionary
        # might be weird because no eos was added?
        with open(path, 'r', encoding='utf-8') as f:
            tokens = 0
            for line in f:
                words = line.split()
                if len(words) == 2: #first line
                    continue
                word = words[0]
                vec = words[1:]
                if len(vec) != 300:
                    continue #this skips the space embedding
                #vec = np.array(list(map(float, vec)))
                vec = list(map(float,vec))
                tokens += 1
                
                self.dictionary.add_word(word, vec)
    def tokenize(self, path, header):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r', encoding='utf-8') as f:
            reader = csv.reader(f)
            tokens = 0
            prev = None
            if header:
                first = True
            else:
                first = False
            tweet_count = 0
            user_idx = -1
            for row in reader:
                if first:
                    first = False
                    continue
                if len(row) is not 6:
                    continue
                
                tweet = row[0]
                label = row[1]
                if not label.isdigit():
                    continue
                extra = row[2:5] #bio, tweet pic, profile pic, user id
                if row[2] != prev: #new user
                    prev = row[2]
                    tweet_count = 0
                    user_idx += 1

                words = tweet.split()
                tokens += len(words)
                for word in words:
                    self.dictionary.add_word(word)

        # Tokenize file content
        with open(path, 'r', encoding='utf-8') as f:
            x = np.zeros(user_idx+1,dtype='object')
            y = np.zeros(user_idx+1,dtype='int')
            #ids = torch.LongTensor(tokens)
            #idxs = torch.LongTensor(user_idx+1)
            #labels = torch.LongTensor(user_idx+1)
            #print(user_idx+1)
            token = 0
            prev = None

            reader = csv.reader(f)
            if header:
                first = True
            else:
                first = False
            user_idx = -1
            for row in reader:
                if first:
                    first = False
                    continue
                if len(row) is not 6:
                    continue
                
                tweet = row[0]
                label = row[1]
                if not label.isdigit():
                    continue
                extra = row[2:5] #bio, tweet pic, profile pic, user id
                if row[2] != prev:
                    tweet_idx = -1
                    user_idx += 1
                    prev = row[2]
                    y[user_idx] = int(label)
                    x[user_idx] = []
                    #print(token, "NEW USER")
                    #idxs[user_idx] = token
                

                words = tweet.split()
                token = 0
                tweet_idx+=1
                if tweet_idx >=20:
                    #print(tweet_idx)
                    continue
                if tweet_idx==0:
                    x[user_idx].append([])
                for word in words:
                    #FLAT STRUCTURE SO THERE'S ONLY ONE 'TWEET'
                    x[user_idx][0].append(self.dictionary.word2idx[word])
                    token+=1
                

        return x, y

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F

#attention functions

def batch_matmul_bias(seq, weight, bias, nonlinearity=''):
    s = None
    bias_dim = bias.size()
    for i in range(seq.size(0)):
        _s = torch.mm(seq[i], weight) 
        _s_bias = _s + bias.expand(bias_dim[0], _s.size()[0]).transpose(0,1)
        if(nonlinearity=='tanh'):
            _s_bias = torch.tanh(_s_bias)
        _s_bias = _s_bias.unsqueeze(0)
        if(s is None):
            s = _s_bias
        else:
            s = torch.cat((s,_s_bias),0)
    return s.squeeze()

def batch_matmul(seq, weight, nonlinearity=''):
    s = None
    for i in range(seq.size(0)):
        _s = torch.mm(seq[i], weight)
        if(nonlinearity=='tanh'):
            _s = torch.tanh(_s)
        _s = _s.unsqueeze(0)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)
    return s.squeeze()

def attention_mul(rnn_outputs, att_weights):
    attn_vectors = None
    for i in range(rnn_outputs.size(0)):
        h_i = rnn_outputs[i]
        a_i = att_weights[i].unsqueeze(1).expand_as(h_i)
        h_i = a_i * h_i
        h_i = h_i.unsqueeze(0)
        if(attn_vectors is None):
            attn_vectors = h_i
        else:
            attn_vectors = torch.cat((attn_vectors,h_i),0)
    return torch.sum(attn_vectors, 0).unsqueeze(0)

'''
def batch_matmul_bias(seq, weight, bias, nonlinearity=''):
    s = None
    bias_dim = bias.size()
    for i in range(seq.size(0)):
        _s = torch.mm(seq[i], weight) 
        _s_bias = _s + bias.expand(bias_dim[0], _s.size()[0]).transpose(0,1)
        if(nonlinearity=='tanh'):
            _s_bias = torch.tanh(_s_bias)
        _s_bias = _s_bias.unsqueeze(0)
        if(s is None):
            s = _s_bias
        else:
            s = torch.cat((s,_s_bias),0)
    return s.squeeze()
    
def batch_matmul(seq, weight, nonlinearity=''):
    s = None
    for i in range(seq.size(0)):
        _s = torch.mm(seq[i], weight)
        if(nonlinearity=='tanh'):
            _s = torch.tanh(_s)
        _s = _s.unsqueeze(0)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)
    return s.squeeze()

def attention_mul(self, rnn_outputs, att_weights):
    attn_vectors = None
    for i in range(rnn_outputs.size(0)):
        h_i = rnn_outputs[i]
        a_i = att_weights[i].unsqueeze(1).expand_as(h_i)
        h_i = a_i * h_i
        h_i = h_i.unsqueeze(0)
        if(attn_vectors is None):
            attn_vectors = h_i
        else:
            attn_vectors = torch.cat((attn_vectors,h_i),0)
    return torch.sum(attn_vectors, 0).unsqueeze(0)
'''
class AttentionWordRNN(nn.Module):
    
    
    def __init__(self, embeds, batch_size, num_tokens, embed_size, word_gru_hidden, dropout, n_classes, bidirectional= True):        
        
        super(AttentionWordRNN, self).__init__()
        
        self.batch_size = batch_size
        self.num_tokens = num_tokens
        self.embed_size = embed_size
        self.word_gru_hidden = word_gru_hidden
        self.bidirectional = bidirectional
        self.drop = nn.Dropout(dropout)
        

        
        
        self.lookup = nn.Embedding(num_tokens, embed_size)

        #init lookup table
        

        
        initrange = 0.1

        k = len(embeds) # the first k indices are pretrained. the rest are unknown
        
        if k is not 0:
            first = np.array(embeds)
            second = np.random.uniform(-initrange,initrange,size=(num_tokens-k,embed_size))
            self.lookup.weight.data.copy_(torch.from_numpy(np.concatenate((first,second),axis=0)))
        else:
            self.lookup.weight.data.uniform_(-initrange, initrange)
        

        if bidirectional == True:
            self.word_gru = nn.GRU(embed_size, word_gru_hidden, bidirectional= True)
            #self.weight_W_word = nn.Parameter(torch.Tensor(2* word_gru_hidden,2*word_gru_hidden))
            #self.bias_word = nn.Parameter(torch.Tensor(2* word_gru_hidden,1))
            #self.weight_proj_word = nn.Parameter(torch.Tensor(2*word_gru_hidden, 1))
            self.final_linear = nn.Linear(2*word_gru_hidden, n_classes)
        else:
            self.word_gru = nn.GRU(embed_size, word_gru_hidden, bidirectional= False)
            #self.weight_W_word = nn.Parameter(torch.Tensor(word_gru_hidden, word_gru_hidden))
            #self.bias_word = nn.Parameter(torch.Tensor(word_gru_hidden,1))
            #self.weight_proj_word = nn.Parameter(torch.Tensor(word_gru_hidden, 1))
            self.final_linear = nn.Linear(word_gru_hidden, n_classes)
            
        self.softmax_word = nn.Softmax()
        #self.word_gru.data.uniform_(-initrange,initrange)
        #self.weight_W_word.data.uniform_(-initrange, initrange)
        #self.weight_proj_word.data.uniform_(-initrange,initrange)
        #self.bias_word.data.uniform_(-initrange,initrange)

        
        
    def forward(self, embed, state_word):
        # embeddings
        #print(embed)
        embedded = self.drop(self.lookup(embed))
        # word level gru
        #state_word = self.drop(state_word) #idk
        output_word, state_word = self.word_gru(embedded, state_word)
        #state_word = self.drop(state_word) #idk
        output_word = self.drop(output_word)
        #print output_word.size()
        #word_squish = self.drop(batch_matmul_bias(output_word, self.weight_W_word,self.bias_word, nonlinearity='tanh'))
        #word_attn = self.drop(batch_matmul(word_squish, self.weight_proj_word))
        #word_attn_norm = self.drop(self.softmax_word(word_attn.transpose(1,0)))
        #word_attn_vectors = self.drop(attention_mul(output_word, word_attn_norm.transpose(1,0)))
        
        #take the average of output
        feature_vec = torch.mean(output_word,0)
        final_map = self.final_linear(feature_vec.squeeze(0))
        return F.log_softmax(final_map), state_word, None
    
    def init_hidden(self):
        if self.bidirectional == True:
            return Variable(torch.zeros(2, self.batch_size, self.word_gru_hidden))
        else:
            return Variable(torch.zeros(1, self.batch_size, self.word_gru_hidden))
'''
class AttentionSentRNN(nn.Module):
    
    
    def __init__(self, batch_size, sent_gru_hidden, word_gru_hidden, n_classes, dropout, bidirectional= True):        
        
        super(AttentionSentRNN, self).__init__()
        
        self.batch_size = batch_size
        self.sent_gru_hidden = sent_gru_hidden
        self.n_classes = n_classes
        self.word_gru_hidden = word_gru_hidden
        self.bidirectional = bidirectional
        
        self.drop = nn.Dropout(dropout)

        initrange = 0.1
        
        
        if bidirectional == True:
            self.sent_gru = nn.GRU(2 * word_gru_hidden, sent_gru_hidden, bidirectional= True)        
            self.weight_W_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden ,2* sent_gru_hidden))
            self.bias_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden,1))
            self.weight_proj_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden, 1))
            self.final_linear = nn.Linear(2* sent_gru_hidden, n_classes)
        else:
            self.sent_gru = nn.GRU(word_gru_hidden, sent_gru_hidden, bidirectional= True)        
            self.weight_W_sent = nn.Parameter(torch.Tensor(sent_gru_hidden ,sent_gru_hidden))
            self.bias_sent = nn.Parameter(torch.Tensor(sent_gru_hidden,1))
            self.weight_proj_sent = nn.Parameter(torch.Tensor(sent_gru_hidden, 1))
            self.final_linear = nn.Linear(sent_gru_hidden, n_classes)
        self.softmax_sent = nn.Softmax()
        self.final_softmax = nn.Softmax()
        self.bias_sent.data.uniform_(-initrange, initrange)
        #self.sent_gru.data.uniform_(-initrange,initrange)
        self.weight_W_sent.data.uniform_(-initrange, initrange)
        self.weight_proj_sent.data.uniform_(-initrange,initrange)
        
        
    def forward(self, word_attention_vectors, state_sent):
        #MANUALLY DROPOUT THE GRU
        #state_word = self.drop(state_sent)
        output_sent, state_sent = self.sent_gru(word_attention_vectors, state_sent)   
        #state_word = self.drop(state_sent)
        output_sent = self.drop(output_sent)
        sent_squish = self.drop(batch_matmul_bias(output_sent, self.weight_W_sent,self.bias_sent, nonlinearity='tanh'))
        sent_attn = self.drop(batch_matmul(sent_squish, self.weight_proj_sent))
        sent_attn_norm = self.drop(self.softmax_sent(sent_attn.transpose(1,0)))
        sent_attn_vectors = self.drop(attention_mul(output_sent, sent_attn_norm.transpose(1,0)))    
        # final classifier
        final_map = self.final_linear(sent_attn_vectors.squeeze(0))
        return F.log_softmax(final_map), state_sent, sent_attn_norm
    
    def init_hidden(self):
        if self.bidirectional == True:
            return Variable(torch.zeros(2, self.batch_size, self.sent_gru_hidden))
        else:
            return Variable(torch.zeros(1, self.batch_size, self.sent_gru_hidden))
'''
# Out:
# "\nclass AttentionSentRNN(nn.Module):\n    \n    \n    def __init__(self, batch_size, sent_gru_hidden, word_gru_hidden, n_classes, dropout, bidirectional= True):        \n        \n        super(AttentionSentRNN, self).__init__()\n        \n        self.batch_size = batch_size\n        self.sent_gru_hidden = sent_gru_hidden\n        self.n_classes = n_classes\n        self.word_gru_hidden = word_gru_hidden\n        self.bidirectional = bidirectional\n        \n        self.drop = nn.Dropout(dropout)\n\n        initrange = 0.1\n        \n        \n        if bidirectional == True:\n            self.sent_gru = nn.GRU(2 * word_gru_hidden, sent_gru_hidden, bidirectional= True)        \n            self.weight_W_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden ,2* sent_gru_hidden))\n            self.bias_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden,1))\n            self.weight_proj_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden, 1))\n            self.final_linear = nn.Linear(2* sent_gru_hidden, n_classes)\n        else:\n            self.sent_gru = nn.GRU(word_gru_hidden, sent_gru_hidden, bidirectional= True)        \n            self.weight_W_sent = nn.Parameter(torch.Tensor(sent_gru_hidden ,sent_gru_hidden))\n            self.bias_sent = nn.Parameter(torch.Tensor(sent_gru_hidden,1))\n            self.weight_proj_sent = nn.Parameter(torch.Tensor(sent_gru_hidden, 1))\n            self.final_linear = nn.Linear(sent_gru_hidden, n_classes)\n        self.softmax_sent = nn.Softmax()\n        self.final_softmax = nn.Softmax()\n        self.bias_sent.data.uniform_(-initrange, initrange)\n        #self.sent_gru.data.uniform_(-initrange,initrange)\n        self.weight_W_sent.data.uniform_(-initrange, initrange)\n        self.weight_proj_sent.data.uniform_(-initrange,initrange)\n        \n        \n    def forward(self, word_attention_vectors, state_sent):\n        #MANUALLY DROPOUT THE GRU\n        #state_word = self.drop(state_sent)\n        output_sent, state_sent = self.sent_gru(word_attention_vectors, state_sent)   \n        #state_word = self.drop(state_sent)\n        output_sent = self.drop(output_sent)\n        sent_squish = self.drop(batch_matmul_bias(output_sent, self.weight_W_sent,self.bias_sent, nonlinearity='tanh'))\n        sent_attn = self.drop(batch_matmul(sent_squish, self.weight_proj_sent))\n        sent_attn_norm = self.drop(self.softmax_sent(sent_attn.transpose(1,0)))\n        sent_attn_vectors = self.drop(attention_mul(output_sent, sent_attn_norm.transpose(1,0)))    \n        # final classifier\n        final_map = self.final_linear(sent_attn_vectors.squeeze(0))\n        return F.log_softmax(final_map), state_sent, sent_attn_norm\n    \n    def init_hidden(self):\n        if self.bidirectional == True:\n            return Variable(torch.zeros(2, self.batch_size, self.sent_gru_hidden))\n        else:\n            return Variable(torch.zeros(1, self.batch_size, self.sent_gru_hidden))\n"

# %%
#import model
#import data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import sklearn.metrics

dropout=0.5
my_batch=64
lang='en'
datapath = './data/'+lang
corpus = Corpus(datapath, lang)
ntokens = len(corpus.dictionary)
pretrain = corpus.dictionary.pretrain_vec

word_attn = AttentionWordRNN(embeds=pretrain, batch_size=my_batch, num_tokens=ntokens, embed_size=300, 
                             word_gru_hidden=100, dropout=dropout, n_classes=2, bidirectional= True)

#sent_attn = AttentionSentRNN(batch_size=my_batch, sent_gru_hidden=100, word_gru_hidden=100, 
#                             n_classes=2, dropout=dropout, bidirectional= True)

def train_data(mini_batch, targets, word_attn_model, word_optimizer, criterion):
    state_word = word_attn_model.init_hidden().cuda()
    #state_sent = sent_attn_model.init_hidden().cuda()
    max_sents, batch_size, max_tokens = mini_batch.size()
    word_optimizer.zero_grad()
    #sent_optimizer.zero_grad()
    #s = None
    y_pred = None
    for i in range(max_sents):
        #torch.cuda.empty_cache()
        _s, state_word, _ = word_attn_model(mini_batch[i,:,:].transpose(0,1), state_word) #train ith user
        #if(s is None):
        if(y_pred is None):
            y_pred = _s
        else:
            y_pred = torch.cat((y_pred,_s),0)            
    #y_pred, state_sent, _ = sent_attn_model(s, state_sent)
    loss = criterion(y_pred.cuda(), targets)

    state_word = None
    #state_sent = None
    max_sents = None
    batch_size = None
    max_tokens = None 
    mini_batch = None
    torch.cuda.empty_cache()
    loss.backward()
    
    word_optimizer.step()
    #sent_optimizer.step()
    
    return loss.data.item()



def get_predictions(val_tokens, word_attn_model):
    max_sents, batch_size, max_tokens = val_tokens.size()
    state_word = word_attn_model.init_hidden().cuda()
    #state_sent = sent_attn_model.init_hidden().cuda()
    s = None
    #print(max_sents, max_tokens, "UHJKSDG")
    for i in range(max_sents):
        _s, state_word, _ = word_attn_model(val_tokens[i,:,:].transpose(0,1), state_word)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)            
    #y_pred, state_sent, _ = sent_attn_model(s, state_sent)    
    return s



#learning_rate = 0.001
#momentum = 0.9
#word_optimizer = torch.optim.SGD(word_attn.parameters(), lr=learning_rate, momentum= momentum)
#sent_optimizer = torch.optim.SGD(sent_attn.parameters(), lr=learning_rate, momentum= momentum)
word_optimizer = torch.optim.Adam(word_attn.parameters())
#sent_optimizer = torch.optim.Adam(sent_attn.parameters())
criterion = nn.NLLLoss()

word_attn.cuda()
#sent_attn.cuda()



def pad_batch(mini_batch):
    mini_batch_size = len(mini_batch)
    max_sent_len = int(np.mean([len(x) for x in mini_batch]))
    max_token_len = int(np.mean([len(val) for sublist in mini_batch for val in sublist]))
    main_matrix = np.zeros((mini_batch_size, max_sent_len, max_token_len), dtype= np.int)
    for i in range(main_matrix.shape[0]):
        for j in range(main_matrix.shape[1]):
            for k in range(main_matrix.shape[2]):
                try:
                    main_matrix[i,j,k] = mini_batch[i][j][k]
                except IndexError:
                    pass
    #return Variable(torch.from_numpy(main_matrix).transpose(0,1))
    return Variable(torch.LongTensor(main_matrix).transpose(0,1))



def test_accuracy_mini_batch(tokens, labels, word_attn):
    y_pred = get_predictions(tokens, word_attn)
    #print("PRED",y_pred)
    _, y_pred = torch.max(y_pred, 1)
    correct = np.ndarray.flatten(y_pred.data.cpu().numpy())
    labels = np.ndarray.flatten(labels.data.cpu().numpy())
    #print("CORR",correct)
    #print("LABELS",labels)
    num_correct = sum(correct == labels)
    return float(num_correct) / len(correct)

def test_accuracy_full_batch(tokens, labels, mini_batch_size, word_attn):
    p = []
    p_nonlinear = []
    l = []
    g = gen_minibatch(tokens, labels, mini_batch_size)
    for token, label in g:
        y_pred = get_predictions(token.cuda(), word_attn)
        #print("BEFORE",y_pred)
        p_nonlinear.append(np.ndarray.flatten(y_pred[:,1].data.cpu().numpy()))
        _, y_pred = torch.max(y_pred, 1)
        #print("AFTER",y_pred)
        p.append(np.ndarray.flatten(y_pred.data.cpu().numpy()))
        l.append(np.ndarray.flatten(label.data.cpu().numpy()))
    p = [item for sublist in p for item in sublist]
    l = [item for sublist in l for item in sublist]
    p_nonlinear = [np.exp(item) for sublist in p_nonlinear for item in sublist]
    p = np.array(p)
    l = np.array(l)
    #print("TOKEN LEN",len(tokens))
    #print("NONLINEAR",p_nonlinear)
    #print("PREDICT",p)
    #print("LABEL",l)
    num_correct = sum(p == l)
    return float(num_correct)/ len(p), sklearn.metrics.roc_auc_score(l, p_nonlinear)

def test_data(mini_batch, targets, word_attn_model):    
    state_word = word_attn_model.init_hidden().cuda()
    #state_sent = sent_attn_model.init_hidden().cuda()
    max_sents, batch_size, max_tokens = mini_batch.size()
    s = None
    for i in range(max_sents):
        _s, state_word, _ = word_attn_model(mini_batch[i,:,:].transpose(0,1), state_word)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)            
    #y_pred, state_sent,_ = sent_attn_model(s, state_sent)
    loss = criterion(s.cuda(), targets)     
    return loss.data.item()

def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert inputs.shape[0] == targets.shape[0]
    if shuffle:
        indices = np.arange(inputs.shape[0])
        np.random.shuffle(indices)
    #print(inputs.shape[0] - batchsize+1, batchsize, "HOO")
    for start_idx in range(0, inputs.shape[0] - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]



def gen_minibatch(tokens, labels, mini_batch_size, shuffle= True):
    for token, label in iterate_minibatches(tokens, labels, mini_batch_size, shuffle= shuffle):
        token = pad_batch(token)
        yield token.cuda(), Variable(torch.LongTensor(label), requires_grad= False).cuda()

def check_val_loss(val_tokens, val_labels, mini_batch_size, word_attn_model):
    val_loss = []
    for token, label in iterate_minibatches(val_tokens, val_labels, mini_batch_size, shuffle= True):
        val_loss.append(test_data(pad_batch(token).cuda(), Variable(torch.LongTensor(label), requires_grad= False).cuda(), 
                                  word_attn_model))
    return np.mean(val_loss)

import time
import math

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def train_early_stopping(mini_batch_size, X_train, y_train, X_test, y_test, word_attn_model,
                         word_attn_optimiser, loss_criterion, num_epoch, 
                         print_val_loss_every = 1000, print_loss_every = 50):
    #for i in word_attn_model.parameters():
        #print(i.data, "PARAM")
    max_eval_acc = 0
    max_train_acc = 0
    max_eval_aucroc = 0
    max_train_aucroc = 0
    word_attn_model.train()
    #sent_attn_model.train()
    start = time.time()
    loss_full = []
    loss_epoch = []
    accuracy_epoch = []
    loss_smooth = []
    accuracy_full = []
    epoch_counter = 0
    g = gen_minibatch(X_train, y_train, mini_batch_size)
    for i in range(1, num_epoch + 1):
        try:
            word_attn_model.train()
            #sent_attn_model.train()
            tokens, labels = next(g)
            loss = train_data(tokens, labels, word_attn_model, word_attn_optimiser, loss_criterion)
            acc = test_accuracy_mini_batch(tokens, labels, word_attn_model)
            accuracy_full.append(acc)
            accuracy_epoch.append(acc)
            loss_full.append(loss)
            loss_epoch.append(loss)
            # print loss every n passes
            if i % print_loss_every == 0:
                print('Loss at %d minibatches, %d epoch,(%s) is %f' %(i, epoch_counter, timeSince(start), np.mean(loss_epoch)))
                print('Accuracy at %d minibatches is %f' % (i, np.mean(accuracy_epoch)))
            # check validation loss every n passes
            if i % print_val_loss_every == 0:
                word_attn_model.eval()
                #sent_attn_model.eval()
                val_loss = check_val_loss(X_test, y_test, mini_batch_size, word_attn_model)
                print('Average training loss at this epoch..minibatch..%d..is %f' % (i, np.mean(loss_epoch)))
                print('Validation loss after %d passes is %f' %(i, val_loss))
                if val_loss > np.mean(loss_full):
                    print('Validation loss is higher than training loss at %d is %f , stopping training!' % (i, val_loss))
                    print('Average training loss at %d is %f' % (i, np.mean(loss_full)))
        except StopIteration:
            epoch_counter += 1
            print('Reached %d epochs' % epoch_counter)
            print('i %d' % i)
            word_attn_model.eval()
            #sent_attn_model.eval()
            acc, aucroc = test_accuracy_full_batch(corpus.X_test, corpus.y_test, my_batch, word_attn)
            if acc>max_eval_acc:
                max_eval_acc = acc
            if aucroc>max_eval_aucroc:
                max_eval_aucroc = aucroc
            print("Test accuracy:",acc)
            print("Max test accruacy:",max_eval_acc)
            print("Test aucroc:",aucroc)
            print("Max test aucroc:",max_eval_aucroc)
            word_attn_model.train()
            #sent_attn_model.train()
            acc, aucroc = test_accuracy_full_batch(corpus.X_train, corpus.y_train, my_batch, word_attn)
            if acc>max_train_acc:
                max_train_acc = acc
            if aucroc>max_train_aucroc:
                max_train_aucroc = aucroc
            print("Train accuracy:",acc)
            print("Max train accruacy:",max_train_acc)
            print("Train aucroc:",aucroc)
            print("Max train aucroc:",max_train_aucroc)
            #if epoch_counter == 1:
                #break
            g = gen_minibatch(X_train, y_train, mini_batch_size)
            loss_epoch = []
            accuracy_epoch = []
            if epoch_counter==20:
                break
    return loss_full

# %%
loss_full= train_early_stopping(my_batch, corpus.X_train, corpus.y_train, corpus.X_test, corpus.y_test, word_attn, word_optimizer, 
                            criterion, 5000, 1, 1)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:169: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Loss at 1 minibatches, 0 epoch,(0m 0s) is 0.699341
# Accuracy at 1 minibatches is 0.625000
# Average training loss at this epoch..minibatch..1..is 0.699341
# Validation loss after 1 passes is 0.690365
# Loss at 2 minibatches, 0 epoch,(0m 0s) is 0.688953
# Accuracy at 2 minibatches is 0.632812
# Average training loss at this epoch..minibatch..2..is 0.688953
# Validation loss after 2 passes is 0.690092
# Validation loss is higher than training loss at 2 is 0.690092 , stopping training!
# Average training loss at 2 is 0.688953
# Loss at 3 minibatches, 0 epoch,(0m 0s) is 0.664035
# Accuracy at 3 minibatches is 0.692708
# Average training loss at this epoch..minibatch..3..is 0.664035
# Validation loss after 3 passes is 0.671080
# Validation loss is higher than training loss at 3 is 0.671080 , stopping training!
# Average training loss at 3 is 0.664035
# Loss at 4 minibatches, 0 epoch,(0m 0s) is 0.650201
# Accuracy at 4 minibatches is 0.707031
# Average training loss at this epoch..minibatch..4..is 0.650201
# Validation loss after 4 passes is 0.717021
# Validation loss is higher than training loss at 4 is 0.717021 , stopping training!
# Average training loss at 4 is 0.650201
# Loss at 5 minibatches, 0 epoch,(0m 1s) is 0.647604
# Accuracy at 5 minibatches is 0.700000
# Average training loss at this epoch..minibatch..5..is 0.647604
# Validation loss after 5 passes is 0.694875
# Validation loss is higher than training loss at 5 is 0.694875 , stopping training!
# Average training loss at 5 is 0.647604
# Loss at 6 minibatches, 0 epoch,(0m 1s) is 0.647526
# Accuracy at 6 minibatches is 0.692708
# Average training loss at this epoch..minibatch..6..is 0.647526
# Validation loss after 6 passes is 0.740248
# Validation loss is higher than training loss at 6 is 0.740248 , stopping training!
# Average training loss at 6 is 0.647526
# Loss at 7 minibatches, 0 epoch,(0m 1s) is 0.630468
# Accuracy at 7 minibatches is 0.707589
# Average training loss at this epoch..minibatch..7..is 0.630468
# Validation loss after 7 passes is 0.677487
# Validation loss is higher than training loss at 7 is 0.677487 , stopping training!
# Average training loss at 7 is 0.630468
# Loss at 8 minibatches, 0 epoch,(0m 1s) is 0.634235
# Accuracy at 8 minibatches is 0.701172
# Average training loss at this epoch..minibatch..8..is 0.634235
# Validation loss after 8 passes is 0.721782
# Validation loss is higher than training loss at 8 is 0.721782 , stopping training!
# Average training loss at 8 is 0.634235
# Loss at 9 minibatches, 0 epoch,(0m 1s) is 0.627581
# Accuracy at 9 minibatches is 0.704861
# Average training loss at this epoch..minibatch..9..is 0.627581
# Validation loss after 9 passes is 0.737258
# Validation loss is higher than training loss at 9 is 0.737258 , stopping training!
# Average training loss at 9 is 0.627581
# Reached 1 epochs
# i 10
# Test accuracy: 0.59375
# Max test accruacy: 0.59375
# Test aucroc: 0.7327935222672064
# Max test aucroc: 0.7327935222672064
# Train accuracy: 0.6979166666666666
# Max train accruacy: 0.6979166666666666
# Train aucroc: 0.6514267741751015
# Max train aucroc: 0.6514267741751015
# Loss at 11 minibatches, 1 epoch,(0m 2s) is 0.555086
# Accuracy at 11 minibatches is 0.750000
# Average training loss at this epoch..minibatch..11..is 0.555086
# Validation loss after 11 passes is 0.700711
# Validation loss is higher than training loss at 11 is 0.700711 , stopping training!
# Average training loss at 11 is 0.620331
# Loss at 12 minibatches, 1 epoch,(0m 2s) is 0.593771
# Accuracy at 12 minibatches is 0.710938
# Average training loss at this epoch..minibatch..12..is 0.593771
# Validation loss after 12 passes is 0.741598
# Validation loss is higher than training loss at 12 is 0.741598 , stopping training!
# Average training loss at 12 is 0.621433
# Loss at 13 minibatches, 1 epoch,(0m 2s) is 0.597471
# Accuracy at 13 minibatches is 0.703125
# Average training loss at this epoch..minibatch..13..is 0.597471
# Validation loss after 13 passes is 0.722402
# Validation loss is higher than training loss at 13 is 0.722402 , stopping training!
# Average training loss at 13 is 0.620053
# Loss at 14 minibatches, 1 epoch,(0m 2s) is 0.612133
# Accuracy at 14 minibatches is 0.683594
# Average training loss at this epoch..minibatch..14..is 0.612133
# Validation loss after 14 passes is 0.671048
# Validation loss is higher than training loss at 14 is 0.671048 , stopping training!
# Average training loss at 14 is 0.622827
# Loss at 15 minibatches, 1 epoch,(0m 2s) is 0.599108
# Accuracy at 15 minibatches is 0.690625
# Average training loss at this epoch..minibatch..15..is 0.599108
# Validation loss after 15 passes is 0.672343
# Validation loss is higher than training loss at 15 is 0.672343 , stopping training!
# Average training loss at 15 is 0.617412
# Loss at 16 minibatches, 1 epoch,(0m 3s) is 0.593137
# Accuracy at 16 minibatches is 0.690104
# Average training loss at this epoch..minibatch..16..is 0.593137
# Validation loss after 16 passes is 0.616023
# Validation loss is higher than training loss at 16 is 0.616023 , stopping training!
# Average training loss at 16 is 0.613803
# Loss at 17 minibatches, 1 epoch,(0m 3s) is 0.576856
# Accuracy at 17 minibatches is 0.703125
# Average training loss at this epoch..minibatch..17..is 0.576856
# Validation loss after 17 passes is 0.664817
# Validation loss is higher than training loss at 17 is 0.664817 , stopping training!
# Average training loss at 17 is 0.605388
# Loss at 18 minibatches, 1 epoch,(0m 3s) is 0.572178
# Accuracy at 18 minibatches is 0.707031
# Average training loss at this epoch..minibatch..18..is 0.572178
# Validation loss after 18 passes is 0.602185
# Validation loss is higher than training loss at 18 is 0.602185 , stopping training!
# Average training loss at 18 is 0.601509
# Loss at 19 minibatches, 1 epoch,(0m 3s) is 0.569204
# Accuracy at 19 minibatches is 0.710069
# Average training loss at this epoch..minibatch..19..is 0.569204
# Validation loss after 19 passes is 0.580717
# Reached 2 epochs
# i 20
# Test accuracy: 0.609375
# Max test accruacy: 0.609375
# Test aucroc: 0.9139139139139141
# Max test aucroc: 0.9139139139139141
# Train accuracy: 0.7170138888888888
# Max train accruacy: 0.7170138888888888
# Train aucroc: 0.8247968247968248
# Max train aucroc: 0.8247968247968248
# Loss at 21 minibatches, 2 epoch,(0m 4s) is 0.569901
# Accuracy at 21 minibatches is 0.734375
# Average training loss at this epoch..minibatch..21..is 0.569901
# Validation loss after 21 passes is 0.578466
# Loss at 22 minibatches, 2 epoch,(0m 4s) is 0.557210
# Accuracy at 22 minibatches is 0.703125
# Average training loss at this epoch..minibatch..22..is 0.557210
# Validation loss after 22 passes is 0.569731
# Loss at 23 minibatches, 2 epoch,(0m 4s) is 0.545821
# Accuracy at 23 minibatches is 0.723958
# Average training loss at this epoch..minibatch..23..is 0.545821
# Validation loss after 23 passes is 0.544177
# Loss at 24 minibatches, 2 epoch,(0m 4s) is 0.532372
# Accuracy at 24 minibatches is 0.738281
# Average training loss at this epoch..minibatch..24..is 0.532372
# Validation loss after 24 passes is 0.526064
# Loss at 25 minibatches, 2 epoch,(0m 4s) is 0.519710
# Accuracy at 25 minibatches is 0.746875
# Average training loss at this epoch..minibatch..25..is 0.519710
# Validation loss after 25 passes is 0.537705
# Loss at 26 minibatches, 2 epoch,(0m 4s) is 0.531473
# Accuracy at 26 minibatches is 0.731771
# Average training loss at this epoch..minibatch..26..is 0.531473
# Validation loss after 26 passes is 0.522093
# Loss at 27 minibatches, 2 epoch,(0m 5s) is 0.526378
# Accuracy at 27 minibatches is 0.736607
# Average training loss at this epoch..minibatch..27..is 0.526378
# Validation loss after 27 passes is 0.476458
# Loss at 28 minibatches, 2 epoch,(0m 5s) is 0.524771
# Accuracy at 28 minibatches is 0.738281
# Average training loss at this epoch..minibatch..28..is 0.524771
# Validation loss after 28 passes is 0.480816
# Loss at 29 minibatches, 2 epoch,(0m 5s) is 0.516426
# Accuracy at 29 minibatches is 0.737847
# Average training loss at this epoch..minibatch..29..is 0.516426
# Validation loss after 29 passes is 0.457910
# Reached 3 epochs
# i 30
# Test accuracy: 0.71875
# Max test accruacy: 0.71875
# Test aucroc: 0.947947947947948
# Max test aucroc: 0.947947947947948
# Train accuracy: 0.765625
# Max train accruacy: 0.765625
# Train aucroc: 0.8818857844198975
# Max train aucroc: 0.8818857844198975
# Loss at 31 minibatches, 3 epoch,(0m 5s) is 0.350556
# Accuracy at 31 minibatches is 0.843750
# Average training loss at this epoch..minibatch..31..is 0.350556
# Validation loss after 31 passes is 0.518040
# Loss at 32 minibatches, 3 epoch,(0m 5s) is 0.379331
# Accuracy at 32 minibatches is 0.820312
# Average training loss at this epoch..minibatch..32..is 0.379331
# Validation loss after 32 passes is 0.520589
# Loss at 33 minibatches, 3 epoch,(0m 6s) is 0.380054
# Accuracy at 33 minibatches is 0.807292
# Average training loss at this epoch..minibatch..33..is 0.380054
# Validation loss after 33 passes is 0.499080
# Loss at 34 minibatches, 3 epoch,(0m 6s) is 0.423531
# Accuracy at 34 minibatches is 0.777344
# Average training loss at this epoch..minibatch..34..is 0.423531
# Validation loss after 34 passes is 0.445313
# Loss at 35 minibatches, 3 epoch,(0m 6s) is 0.426119
# Accuracy at 35 minibatches is 0.784375
# Average training loss at this epoch..minibatch..35..is 0.426119
# Validation loss after 35 passes is 0.420218
# Loss at 36 minibatches, 3 epoch,(0m 6s) is 0.436862
# Accuracy at 36 minibatches is 0.783854
# Average training loss at this epoch..minibatch..36..is 0.436862
# Validation loss after 36 passes is 0.317430
# Loss at 37 minibatches, 3 epoch,(0m 6s) is 0.421945
# Accuracy at 37 minibatches is 0.803571
# Average training loss at this epoch..minibatch..37..is 0.421945
# Validation loss after 37 passes is 0.282982
# Loss at 38 minibatches, 3 epoch,(0m 7s) is 0.403770
# Accuracy at 38 minibatches is 0.820312
# Average training loss at this epoch..minibatch..38..is 0.403770
# Validation loss after 38 passes is 0.263475
# Loss at 39 minibatches, 3 epoch,(0m 7s) is 0.392784
# Accuracy at 39 minibatches is 0.829861
# Average training loss at this epoch..minibatch..39..is 0.392784
# Validation loss after 39 passes is 0.235904
# Reached 4 epochs
# i 40
# Test accuracy: 0.9375
# Max test accruacy: 0.9375
# Test aucroc: 0.9851190476190477
# Max test aucroc: 0.9851190476190477
# Train accuracy: 0.9079861111111112
# Max train accruacy: 0.9079861111111112
# Train aucroc: 0.9519212840115321
# Max train aucroc: 0.9519212840115321
# Loss at 41 minibatches, 4 epoch,(0m 7s) is 0.337411
# Accuracy at 41 minibatches is 0.875000
# Average training loss at this epoch..minibatch..41..is 0.337411
# Validation loss after 41 passes is 0.238392
# Loss at 42 minibatches, 4 epoch,(0m 7s) is 0.311299
# Accuracy at 42 minibatches is 0.882812
# Average training loss at this epoch..minibatch..42..is 0.311299
# Validation loss after 42 passes is 0.253520
# Loss at 43 minibatches, 4 epoch,(0m 7s) is 0.258088
# Accuracy at 43 minibatches is 0.911458
# Average training loss at this epoch..minibatch..43..is 0.258088
# Validation loss after 43 passes is 0.286917
# Loss at 44 minibatches, 4 epoch,(0m 8s) is 0.226470
# Accuracy at 44 minibatches is 0.929688
# Average training loss at this epoch..minibatch..44..is 0.226470
# Validation loss after 44 passes is 0.354063
# Loss at 45 minibatches, 4 epoch,(0m 8s) is 0.238053
# Accuracy at 45 minibatches is 0.925000
# Average training loss at this epoch..minibatch..45..is 0.238053
# Validation loss after 45 passes is 0.501920
# Validation loss is higher than training loss at 45 is 0.501920 , stopping training!
# Average training loss at 45 is 0.491323
# Loss at 46 minibatches, 4 epoch,(0m 8s) is 0.247718
# Accuracy at 46 minibatches is 0.927083
# Average training loss at this epoch..minibatch..46..is 0.247718
# Validation loss after 46 passes is 0.484237
# Loss at 47 minibatches, 4 epoch,(0m 8s) is 0.244774
# Accuracy at 47 minibatches is 0.930804
# Average training loss at this epoch..minibatch..47..is 0.244774
# Validation loss after 47 passes is 0.331983
# Loss at 48 minibatches, 4 epoch,(0m 8s) is 0.236336
# Accuracy at 48 minibatches is 0.935547
# Average training loss at this epoch..minibatch..48..is 0.236336
# Validation loss after 48 passes is 0.235195
# Loss at 49 minibatches, 4 epoch,(0m 9s) is 0.223273
# Accuracy at 49 minibatches is 0.937500
# Average training loss at this epoch..minibatch..49..is 0.223273
# Validation loss after 49 passes is 0.344674
# Reached 5 epochs
# i 50
# Test accuracy: 0.875
# Max test accruacy: 0.9375
# Test aucroc: 0.9822660098522168
# Max test aucroc: 0.9851190476190477
# Train accuracy: 0.9409722222222222
# Max train accruacy: 0.9409722222222222
# Train aucroc: 0.9802698518026985
# Max train aucroc: 0.9802698518026985
# Loss at 51 minibatches, 5 epoch,(0m 9s) is 0.097133
# Accuracy at 51 minibatches is 0.968750
# Average training loss at this epoch..minibatch..51..is 0.097133
# Validation loss after 51 passes is 0.223572
# Loss at 52 minibatches, 5 epoch,(0m 9s) is 0.124496
# Accuracy at 52 minibatches is 0.953125
# Average training loss at this epoch..minibatch..52..is 0.124496
# Validation loss after 52 passes is 0.244076
# Loss at 53 minibatches, 5 epoch,(0m 9s) is 0.182465
# Accuracy at 53 minibatches is 0.942708
# Average training loss at this epoch..minibatch..53..is 0.182465
# Validation loss after 53 passes is 0.267518
# Loss at 54 minibatches, 5 epoch,(0m 9s) is 0.159253
# Accuracy at 54 minibatches is 0.953125
# Average training loss at this epoch..minibatch..54..is 0.159253
# Validation loss after 54 passes is 0.287381
# Loss at 55 minibatches, 5 epoch,(0m 10s) is 0.165562
# Accuracy at 55 minibatches is 0.953125
# Average training loss at this epoch..minibatch..55..is 0.165562
# Validation loss after 55 passes is 0.256377
# Loss at 56 minibatches, 5 epoch,(0m 10s) is 0.152017
# Accuracy at 56 minibatches is 0.955729
# Average training loss at this epoch..minibatch..56..is 0.152017
# Validation loss after 56 passes is 0.437855
# Validation loss is higher than training loss at 56 is 0.437855 , stopping training!
# Average training loss at 56 is 0.428932
# Loss at 57 minibatches, 5 epoch,(0m 10s) is 0.168571
# Accuracy at 57 minibatches is 0.948661
# Average training loss at this epoch..minibatch..57..is 0.168571
# Validation loss after 57 passes is 0.361533
# Loss at 58 minibatches, 5 epoch,(0m 10s) is 0.162942
# Accuracy at 58 minibatches is 0.951172
# Average training loss at this epoch..minibatch..58..is 0.162942
# Validation loss after 58 passes is 0.440523
# Validation loss is higher than training loss at 58 is 0.440523 , stopping training!
# Average training loss at 58 is 0.420131
# Loss at 59 minibatches, 5 epoch,(0m 10s) is 0.149615
# Accuracy at 59 minibatches is 0.956597
# Average training loss at this epoch..minibatch..59..is 0.149615
# Validation loss after 59 passes is 0.503347
# Validation loss is higher than training loss at 59 is 0.503347 , stopping training!
# Average training loss at 59 is 0.413147
# Reached 6 epochs
# i 60
# Test accuracy: 0.859375
# Max test accruacy: 0.9375
# Test aucroc: 0.9819724284199365
# Max test aucroc: 0.9851190476190477
# Train accuracy: 0.9774305555555556
# Max train accruacy: 0.9774305555555556
# Train aucroc: 0.9931669162438393
# Max train aucroc: 0.9931669162438393
# Loss at 61 minibatches, 6 epoch,(0m 11s) is 0.024079
# Accuracy at 61 minibatches is 1.000000
# Average training loss at this epoch..minibatch..61..is 0.024079
# Validation loss after 61 passes is 0.467094
# Validation loss is higher than training loss at 61 is 0.467094 , stopping training!
# Average training loss at 61 is 0.406073
# Loss at 62 minibatches, 6 epoch,(0m 11s) is 0.024212
# Accuracy at 62 minibatches is 1.000000
# Average training loss at this epoch..minibatch..62..is 0.024212
# Validation loss after 62 passes is 0.567248
# Validation loss is higher than training loss at 62 is 0.567248 , stopping training!
# Average training loss at 62 is 0.399257
# Loss at 63 minibatches, 6 epoch,(0m 11s) is 0.043016
# Accuracy at 63 minibatches is 0.984375
# Average training loss at this epoch..minibatch..63..is 0.043016
# Validation loss after 63 passes is 0.532166
# Validation loss is higher than training loss at 63 is 0.532166 , stopping training!
# Average training loss at 63 is 0.393667
# Loss at 64 minibatches, 6 epoch,(0m 11s) is 0.069875
# Accuracy at 64 minibatches is 0.976562
# Average training loss at this epoch..minibatch..64..is 0.069875
# Validation loss after 64 passes is 0.458589
# Validation loss is higher than training loss at 64 is 0.458589 , stopping training!
# Average training loss at 64 is 0.389473
# Loss at 65 minibatches, 6 epoch,(0m 11s) is 0.072905
# Accuracy at 65 minibatches is 0.978125
# Average training loss at this epoch..minibatch..65..is 0.072905
# Validation loss after 65 passes is 0.512905
# Validation loss is higher than training loss at 65 is 0.512905 , stopping training!
# Average training loss at 65 is 0.384313
# Loss at 66 minibatches, 6 epoch,(0m 12s) is 0.076880
# Accuracy at 66 minibatches is 0.976562
# Average training loss at this epoch..minibatch..66..is 0.076880
# Validation loss after 66 passes is 0.354883
# Loss at 67 minibatches, 6 epoch,(0m 12s) is 0.074270
# Accuracy at 67 minibatches is 0.975446
# Average training loss at this epoch..minibatch..67..is 0.074270
# Validation loss after 67 passes is 0.382345
# Validation loss is higher than training loss at 67 is 0.382345 , stopping training!
# Average training loss at 67 is 0.374260
# Loss at 68 minibatches, 6 epoch,(0m 12s) is 0.076786
# Accuracy at 68 minibatches is 0.974609
# Average training loss at this epoch..minibatch..68..is 0.076786
# Validation loss after 68 passes is 0.240006
# Loss at 69 minibatches, 6 epoch,(0m 12s) is 0.073376
# Accuracy at 69 minibatches is 0.977431
# Average training loss at this epoch..minibatch..69..is 0.073376
# Validation loss after 69 passes is 0.367075
# Validation loss is higher than training loss at 69 is 0.367075 , stopping training!
# Average training loss at 69 is 0.364608
# Reached 7 epochs
# i 70
# Test accuracy: 0.859375
# Max test accruacy: 0.9375
# Test aucroc: 0.968968968968969
# Max test aucroc: 0.9851190476190477
# Train accuracy: 0.9826388888888888
# Max train accruacy: 0.9826388888888888
# Train aucroc: 0.9992176180817154
# Max train aucroc: 0.9992176180817154
# Loss at 71 minibatches, 7 epoch,(0m 12s) is 0.085994
# Accuracy at 71 minibatches is 0.968750
# Average training loss at this epoch..minibatch..71..is 0.085994
# Validation loss after 71 passes is 0.294448
# Loss at 72 minibatches, 7 epoch,(0m 13s) is 0.062462
# Accuracy at 72 minibatches is 0.984375
# Average training loss at this epoch..minibatch..72..is 0.062462
# Validation loss after 72 passes is 0.248955
# Loss at 73 minibatches, 7 epoch,(0m 13s) is 0.055545
# Accuracy at 73 minibatches is 0.984375
# Average training loss at this epoch..minibatch..73..is 0.055545
# Validation loss after 73 passes is 0.382365
# Validation loss is higher than training loss at 73 is 0.382365 , stopping training!
# Average training loss at 73 is 0.350560
# Loss at 74 minibatches, 7 epoch,(0m 13s) is 0.049537
# Accuracy at 74 minibatches is 0.988281
# Average training loss at this epoch..minibatch..74..is 0.049537
# Validation loss after 74 passes is 0.336285
# Loss at 75 minibatches, 7 epoch,(0m 13s) is 0.044249
# Accuracy at 75 minibatches is 0.990625
# Average training loss at this epoch..minibatch..75..is 0.044249
# Validation loss after 75 passes is 0.458531
# Validation loss is higher than training loss at 75 is 0.458531 , stopping training!
# Average training loss at 75 is 0.341053
# Loss at 76 minibatches, 7 epoch,(0m 13s) is 0.040459
# Accuracy at 76 minibatches is 0.992188
# Average training loss at this epoch..minibatch..76..is 0.040459
# Validation loss after 76 passes is 0.497373
# Validation loss is higher than training loss at 76 is 0.497373 , stopping training!
# Average training loss at 76 is 0.336421
# Loss at 77 minibatches, 7 epoch,(0m 14s) is 0.042669
# Accuracy at 77 minibatches is 0.991071
# Average training loss at this epoch..minibatch..77..is 0.042669
# Validation loss after 77 passes is 0.491785
# Validation loss is higher than training loss at 77 is 0.491785 , stopping training!
# Average training loss at 77 is 0.332414
# Loss at 78 minibatches, 7 epoch,(0m 14s) is 0.039885
# Accuracy at 78 minibatches is 0.992188
# Average training loss at this epoch..minibatch..78..is 0.039885
# Validation loss after 78 passes is 0.395877
# Validation loss is higher than training loss at 78 is 0.395877 , stopping training!
# Average training loss at 78 is 0.328020
# Loss at 79 minibatches, 7 epoch,(0m 14s) is 0.038773
# Accuracy at 79 minibatches is 0.993056
# Average training loss at this epoch..minibatch..79..is 0.038773
# Validation loss after 79 passes is 0.512791
# Validation loss is higher than training loss at 79 is 0.512791 , stopping training!
# Average training loss at 79 is 0.323879
# Reached 8 epochs
# i 80
# Test accuracy: 0.890625
# Max test accruacy: 0.9375
# Test aucroc: 0.973973973973974
# Max test aucroc: 0.9851190476190477
# Train accuracy: 0.9982638888888888
# Max train accruacy: 0.9982638888888888
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 81 minibatches, 8 epoch,(0m 14s) is 0.008980
# Accuracy at 81 minibatches is 1.000000
# Average training loss at this epoch..minibatch..81..is 0.008980
# Validation loss after 81 passes is 0.412488
# Validation loss is higher than training loss at 81 is 0.412488 , stopping training!
# Average training loss at 81 is 0.319565
# Loss at 82 minibatches, 8 epoch,(0m 14s) is 0.009528
# Accuracy at 82 minibatches is 0.992188
# Average training loss at this epoch..minibatch..82..is 0.009528
# Validation loss after 82 passes is 0.411539
# Validation loss is higher than training loss at 82 is 0.411539 , stopping training!
# Average training loss at 82 is 0.315383
# Loss at 83 minibatches, 8 epoch,(0m 15s) is 0.009195
# Accuracy at 83 minibatches is 0.994792
# Average training loss at this epoch..minibatch..83..is 0.009195
# Validation loss after 83 passes is 0.355693
# Validation loss is higher than training loss at 83 is 0.355693 , stopping training!
# Average training loss at 83 is 0.311292
# Loss at 84 minibatches, 8 epoch,(0m 15s) is 0.010031
# Accuracy at 84 minibatches is 0.996094
# Average training loss at this epoch..minibatch..84..is 0.010031
# Validation loss after 84 passes is 0.480019
# Validation loss is higher than training loss at 84 is 0.480019 , stopping training!
# Average training loss at 84 is 0.307361
# Loss at 85 minibatches, 8 epoch,(0m 15s) is 0.010090
# Accuracy at 85 minibatches is 0.996875
# Average training loss at this epoch..minibatch..85..is 0.010090
# Validation loss after 85 passes is 0.570539
# Validation loss is higher than training loss at 85 is 0.570539 , stopping training!
# Average training loss at 85 is 0.303503
# Loss at 86 minibatches, 8 epoch,(0m 15s) is 0.009935
# Accuracy at 86 minibatches is 0.997396
# Average training loss at this epoch..minibatch..86..is 0.009935
# Validation loss after 86 passes is 0.580703
# Validation loss is higher than training loss at 86 is 0.580703 , stopping training!
# Average training loss at 86 is 0.299729
# Loss at 87 minibatches, 8 epoch,(0m 15s) is 0.009593
# Accuracy at 87 minibatches is 0.997768
# Average training loss at this epoch..minibatch..87..is 0.009593
# Validation loss after 87 passes is 0.582591
# Validation loss is higher than training loss at 87 is 0.582591 , stopping training!
# Average training loss at 87 is 0.296031
# Loss at 88 minibatches, 8 epoch,(0m 16s) is 0.009785
# Accuracy at 88 minibatches is 0.998047
# Average training loss at this epoch..minibatch..88..is 0.009785
# Validation loss after 88 passes is 0.771206
# Validation loss is higher than training loss at 88 is 0.771206 , stopping training!
# Average training loss at 88 is 0.292469
# Loss at 89 minibatches, 8 epoch,(0m 16s) is 0.009615
# Accuracy at 89 minibatches is 0.998264
# Average training loss at this epoch..minibatch..89..is 0.009615
# Validation loss after 89 passes is 0.785738
# Validation loss is higher than training loss at 89 is 0.785738 , stopping training!
# Average training loss at 89 is 0.288961
# Reached 9 epochs
# i 90
# Test accuracy: 0.890625
# Max test accruacy: 0.9375
# Test aucroc: 0.9706477732793521
# Max test aucroc: 0.9851190476190477
# Train accuracy: 0.9982638888888888
# Max train accruacy: 0.9982638888888888
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 91 minibatches, 9 epoch,(0m 16s) is 0.043956
# Accuracy at 91 minibatches is 0.984375
# Average training loss at this epoch..minibatch..91..is 0.043956
# Validation loss after 91 passes is 0.688654
# Validation loss is higher than training loss at 91 is 0.688654 , stopping training!
# Average training loss at 91 is 0.285973
# Loss at 92 minibatches, 9 epoch,(0m 16s) is 0.024208
# Accuracy at 92 minibatches is 0.992188
# Average training loss at this epoch..minibatch..92..is 0.024208
# Validation loss after 92 passes is 0.743352
# Validation loss is higher than training loss at 92 is 0.743352 , stopping training!
# Average training loss at 92 is 0.282581
# Loss at 93 minibatches, 9 epoch,(0m 16s) is 0.042809
# Accuracy at 93 minibatches is 0.994792
# Average training loss at this epoch..minibatch..93..is 0.042809
# Validation loss after 93 passes is 0.658776
# Validation loss is higher than training loss at 93 is 0.658776 , stopping training!
# Average training loss at 93 is 0.280170
# Loss at 94 minibatches, 9 epoch,(0m 17s) is 0.033086
# Accuracy at 94 minibatches is 0.996094
# Average training loss at this epoch..minibatch..94..is 0.033086
# Validation loss after 94 passes is 0.760615
# Validation loss is higher than training loss at 94 is 0.760615 , stopping training!
# Average training loss at 94 is 0.276920
# Loss at 95 minibatches, 9 epoch,(0m 17s) is 0.026819
# Accuracy at 95 minibatches is 0.996875
# Average training loss at this epoch..minibatch..95..is 0.026819
# Validation loss after 95 passes is 0.786272
# Validation loss is higher than training loss at 95 is 0.786272 , stopping training!
# Average training loss at 95 is 0.273720
# Loss at 96 minibatches, 9 epoch,(0m 17s) is 0.022961
# Accuracy at 96 minibatches is 0.997396
# Average training loss at this epoch..minibatch..96..is 0.022961
# Validation loss after 96 passes is 0.693704
# Validation loss is higher than training loss at 96 is 0.693704 , stopping training!
# Average training loss at 96 is 0.270616
# Loss at 97 minibatches, 9 epoch,(0m 17s) is 0.020361
# Accuracy at 97 minibatches is 0.997768
# Average training loss at this epoch..minibatch..97..is 0.020361
# Validation loss after 97 passes is 0.823933
# Validation loss is higher than training loss at 97 is 0.823933 , stopping training!
# Average training loss at 97 is 0.267595
# Loss at 98 minibatches, 9 epoch,(0m 17s) is 0.018187
# Accuracy at 98 minibatches is 0.998047
# Average training loss at this epoch..minibatch..98..is 0.018187
# Validation loss after 98 passes is 0.824019
# Validation loss is higher than training loss at 98 is 0.824019 , stopping training!
# Average training loss at 98 is 0.264622
# Loss at 99 minibatches, 9 epoch,(0m 17s) is 0.016719
# Accuracy at 99 minibatches is 0.998264
# Average training loss at this epoch..minibatch..99..is 0.016719
# Validation loss after 99 passes is 0.849143
# Validation loss is higher than training loss at 99 is 0.849143 , stopping training!
# Average training loss at 99 is 0.261737
# Reached 10 epochs
# i 100
# Test accuracy: 0.859375
# Max test accruacy: 0.9375
# Test aucroc: 0.957957957957958
# Max test aucroc: 0.9851190476190477
# Train accuracy: 0.9982638888888888
# Max train accruacy: 0.9982638888888888
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 101 minibatches, 10 epoch,(0m 18s) is 0.004068
# Accuracy at 101 minibatches is 1.000000
# Average training loss at this epoch..minibatch..101..is 0.004068
# Validation loss after 101 passes is 0.595641
# Validation loss is higher than training loss at 101 is 0.595641 , stopping training!
# Average training loss at 101 is 0.258905
# Loss at 102 minibatches, 10 epoch,(0m 18s) is 0.018587
# Accuracy at 102 minibatches is 1.000000
# Average training loss at this epoch..minibatch..102..is 0.018587
# Validation loss after 102 passes is 0.624703
# Validation loss is higher than training loss at 102 is 0.624703 , stopping training!
# Average training loss at 102 is 0.256451
# Loss at 103 minibatches, 10 epoch,(0m 18s) is 0.012971
# Accuracy at 103 minibatches is 1.000000
# Average training loss at this epoch..minibatch..103..is 0.012971
# Validation loss after 103 passes is 0.896867
# Validation loss is higher than training loss at 103 is 0.896867 , stopping training!
# Average training loss at 103 is 0.253712
# Loss at 104 minibatches, 10 epoch,(0m 18s) is 0.010220
# Accuracy at 104 minibatches is 1.000000
# Average training loss at this epoch..minibatch..104..is 0.010220
# Validation loss after 104 passes is 0.702082
# Validation loss is higher than training loss at 104 is 0.702082 , stopping training!
# Average training loss at 104 is 0.251034
# Loss at 105 minibatches, 10 epoch,(0m 19s) is 0.008628
# Accuracy at 105 minibatches is 1.000000
# Average training loss at this epoch..minibatch..105..is 0.008628
# Validation loss after 105 passes is 0.836919
# Validation loss is higher than training loss at 105 is 0.836919 , stopping training!
# Average training loss at 105 is 0.248415
# Loss at 106 minibatches, 10 epoch,(0m 19s) is 0.018540
# Accuracy at 106 minibatches is 1.000000
# Average training loss at this epoch..minibatch..106..is 0.018540
# Validation loss after 106 passes is 0.808505
# Validation loss is higher than training loss at 106 is 0.808505 , stopping training!
# Average training loss at 106 is 0.246537
# Loss at 107 minibatches, 10 epoch,(0m 19s) is 0.016048
# Accuracy at 107 minibatches is 1.000000
# Average training loss at this epoch..minibatch..107..is 0.016048
# Validation loss after 107 passes is 0.689830
# Validation loss is higher than training loss at 107 is 0.689830 , stopping training!
# Average training loss at 107 is 0.244006
# Loss at 108 minibatches, 10 epoch,(0m 19s) is 0.014198
# Accuracy at 108 minibatches is 1.000000
# Average training loss at this epoch..minibatch..108..is 0.014198
# Validation loss after 108 passes is 0.762061
# Validation loss is higher than training loss at 108 is 0.762061 , stopping training!
# Average training loss at 108 is 0.241529
# Loss at 109 minibatches, 10 epoch,(0m 19s) is 0.012846
# Accuracy at 109 minibatches is 1.000000
# Average training loss at this epoch..minibatch..109..is 0.012846
# Validation loss after 109 passes is 0.661934
# Validation loss is higher than training loss at 109 is 0.661934 , stopping training!
# Average training loss at 109 is 0.239110
# Reached 11 epochs
# i 110
# Test accuracy: 0.875
# Max test accruacy: 0.9375
# Test aucroc: 0.9821428571428571
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 111 minibatches, 11 epoch,(0m 20s) is 0.002070
# Accuracy at 111 minibatches is 0.984375
# Average training loss at this epoch..minibatch..111..is 0.002070
# Validation loss after 111 passes is 0.840580
# Validation loss is higher than training loss at 111 is 0.840580 , stopping training!
# Average training loss at 111 is 0.236740
# Loss at 112 minibatches, 11 epoch,(0m 20s) is 0.002022
# Accuracy at 112 minibatches is 0.992188
# Average training loss at this epoch..minibatch..112..is 0.002022
# Validation loss after 112 passes is 0.717456
# Validation loss is higher than training loss at 112 is 0.717456 , stopping training!
# Average training loss at 112 is 0.234415
# Loss at 113 minibatches, 11 epoch,(0m 20s) is 0.002747
# Accuracy at 113 minibatches is 0.994792
# Average training loss at this epoch..minibatch..113..is 0.002747
# Validation loss after 113 passes is 0.970455
# Validation loss is higher than training loss at 113 is 0.970455 , stopping training!
# Average training loss at 113 is 0.232158
# Loss at 114 minibatches, 11 epoch,(0m 20s) is 0.002676
# Accuracy at 114 minibatches is 0.992188
# Average training loss at this epoch..minibatch..114..is 0.002676
# Validation loss after 114 passes is 0.791876
# Validation loss is higher than training loss at 114 is 0.791876 , stopping training!
# Average training loss at 114 is 0.229928
# Loss at 115 minibatches, 11 epoch,(0m 21s) is 0.002606
# Accuracy at 115 minibatches is 0.993750
# Average training loss at this epoch..minibatch..115..is 0.002606
# Validation loss after 115 passes is 0.884413
# Validation loss is higher than training loss at 115 is 0.884413 , stopping training!
# Average training loss at 115 is 0.227740
# Loss at 116 minibatches, 11 epoch,(0m 21s) is 0.002721
# Accuracy at 116 minibatches is 0.989583
# Average training loss at this epoch..minibatch..116..is 0.002721
# Validation loss after 116 passes is 0.924043
# Validation loss is higher than training loss at 116 is 0.924043 , stopping training!
# Average training loss at 116 is 0.225602
# Loss at 117 minibatches, 11 epoch,(0m 21s) is 0.002710
# Accuracy at 117 minibatches is 0.991071
# Average training loss at this epoch..minibatch..117..is 0.002710
# Validation loss after 117 passes is 0.979259
# Validation loss is higher than training loss at 117 is 0.979259 , stopping training!
# Average training loss at 117 is 0.223499
# Loss at 118 minibatches, 11 epoch,(0m 21s) is 0.002801
# Accuracy at 118 minibatches is 0.992188
# Average training loss at this epoch..minibatch..118..is 0.002801
# Validation loss after 118 passes is 1.022053
# Validation loss is higher than training loss at 118 is 1.022053 , stopping training!
# Average training loss at 118 is 0.221442
# Loss at 119 minibatches, 11 epoch,(0m 21s) is 0.007544
# Accuracy at 119 minibatches is 0.991319
# Average training loss at this epoch..minibatch..119..is 0.007544
# Validation loss after 119 passes is 0.890709
# Validation loss is higher than training loss at 119 is 0.890709 , stopping training!
# Average training loss at 119 is 0.219813
# Reached 12 epochs
# i 120
# Test accuracy: 0.828125
# Max test accruacy: 0.9375
# Test aucroc: 0.9719719719719719
# Max test aucroc: 0.9851190476190477
# Train accuracy: 0.9965277777777778
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 121 minibatches, 12 epoch,(0m 22s) is 0.002001
# Accuracy at 121 minibatches is 1.000000
# Average training loss at this epoch..minibatch..121..is 0.002001
# Validation loss after 121 passes is 1.011555
# Validation loss is higher than training loss at 121 is 1.011555 , stopping training!
# Average training loss at 121 is 0.217815
# Loss at 122 minibatches, 12 epoch,(0m 22s) is 0.002974
# Accuracy at 122 minibatches is 1.000000
# Average training loss at this epoch..minibatch..122..is 0.002974
# Validation loss after 122 passes is 0.973426
# Validation loss is higher than training loss at 122 is 0.973426 , stopping training!
# Average training loss at 122 is 0.215870
# Loss at 123 minibatches, 12 epoch,(0m 22s) is 0.003116
# Accuracy at 123 minibatches is 1.000000
# Average training loss at this epoch..minibatch..123..is 0.003116
# Validation loss after 123 passes is 1.109096
# Validation loss is higher than training loss at 123 is 1.109096 , stopping training!
# Average training loss at 123 is 0.213956
# Loss at 124 minibatches, 12 epoch,(0m 22s) is 0.013402
# Accuracy at 124 minibatches is 0.996094
# Average training loss at this epoch..minibatch..124..is 0.013402
# Validation loss after 124 passes is 0.871064
# Validation loss is higher than training loss at 124 is 0.871064 , stopping training!
# Average training loss at 124 is 0.212441
# Loss at 125 minibatches, 12 epoch,(0m 22s) is 0.011207
# Accuracy at 125 minibatches is 0.996875
# Average training loss at this epoch..minibatch..125..is 0.011207
# Validation loss after 125 passes is 0.885200
# Validation loss is higher than training loss at 125 is 0.885200 , stopping training!
# Average training loss at 125 is 0.210583
# Loss at 126 minibatches, 12 epoch,(0m 23s) is 0.009847
# Accuracy at 126 minibatches is 0.997396
# Average training loss at this epoch..minibatch..126..is 0.009847
# Validation loss after 126 passes is 0.738545
# Validation loss is higher than training loss at 126 is 0.738545 , stopping training!
# Average training loss at 126 is 0.208762
# Loss at 127 minibatches, 12 epoch,(0m 23s) is 0.009109
# Accuracy at 127 minibatches is 0.997768
# Average training loss at this epoch..minibatch..127..is 0.009109
# Validation loss after 127 passes is 0.841574
# Validation loss is higher than training loss at 127 is 0.841574 , stopping training!
# Average training loss at 127 is 0.206988
# Loss at 128 minibatches, 12 epoch,(0m 23s) is 0.008179
# Accuracy at 128 minibatches is 0.998047
# Average training loss at this epoch..minibatch..128..is 0.008179
# Validation loss after 128 passes is 0.720547
# Validation loss is higher than training loss at 128 is 0.720547 , stopping training!
# Average training loss at 128 is 0.205217
# Loss at 129 minibatches, 12 epoch,(0m 23s) is 0.007390
# Accuracy at 129 minibatches is 0.998264
# Average training loss at this epoch..minibatch..129..is 0.007390
# Validation loss after 129 passes is 0.537439
# Validation loss is higher than training loss at 129 is 0.537439 , stopping training!
# Average training loss at 129 is 0.203473
# Reached 13 epochs
# i 130
# Test accuracy: 0.875
# Max test accruacy: 0.9375
# Test aucroc: 0.967487684729064
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 131 minibatches, 13 epoch,(0m 24s) is 0.001419
# Accuracy at 131 minibatches is 1.000000
# Average training loss at this epoch..minibatch..131..is 0.001419
# Validation loss after 131 passes is 0.645900
# Validation loss is higher than training loss at 131 is 0.645900 , stopping training!
# Average training loss at 131 is 0.201760
# Loss at 132 minibatches, 13 epoch,(0m 24s) is 0.001329
# Accuracy at 132 minibatches is 1.000000
# Average training loss at this epoch..minibatch..132..is 0.001329
# Validation loss after 132 passes is 0.571825
# Validation loss is higher than training loss at 132 is 0.571825 , stopping training!
# Average training loss at 132 is 0.200075
# Loss at 133 minibatches, 13 epoch,(0m 24s) is 0.001389
# Accuracy at 133 minibatches is 1.000000
# Average training loss at this epoch..minibatch..133..is 0.001389
# Validation loss after 133 passes is 0.555206
# Validation loss is higher than training loss at 133 is 0.555206 , stopping training!
# Average training loss at 133 is 0.198421
# Loss at 134 minibatches, 13 epoch,(0m 24s) is 0.001253
# Accuracy at 134 minibatches is 1.000000
# Average training loss at this epoch..minibatch..134..is 0.001253
# Validation loss after 134 passes is 0.614042
# Validation loss is higher than training loss at 134 is 0.614042 , stopping training!
# Average training loss at 134 is 0.196788
# Loss at 135 minibatches, 13 epoch,(0m 24s) is 0.001263
# Accuracy at 135 minibatches is 1.000000
# Average training loss at this epoch..minibatch..135..is 0.001263
# Validation loss after 135 passes is 0.607627
# Validation loss is higher than training loss at 135 is 0.607627 , stopping training!
# Average training loss at 135 is 0.195185
# Loss at 136 minibatches, 13 epoch,(0m 24s) is 0.001172
# Accuracy at 136 minibatches is 1.000000
# Average training loss at this epoch..minibatch..136..is 0.001172
# Validation loss after 136 passes is 0.641569
# Validation loss is higher than training loss at 136 is 0.641569 , stopping training!
# Average training loss at 136 is 0.193604
# Loss at 137 minibatches, 13 epoch,(0m 25s) is 0.009650
# Accuracy at 137 minibatches is 1.000000
# Average training loss at this epoch..minibatch..137..is 0.009650
# Validation loss after 137 passes is 0.506674
# Validation loss is higher than training loss at 137 is 0.506674 , stopping training!
# Average training loss at 137 is 0.192531
# Loss at 138 minibatches, 13 epoch,(0m 25s) is 0.008529
# Accuracy at 138 minibatches is 1.000000
# Average training loss at this epoch..minibatch..138..is 0.008529
# Validation loss after 138 passes is 0.642945
# Validation loss is higher than training loss at 138 is 0.642945 , stopping training!
# Average training loss at 138 is 0.190996
# Loss at 139 minibatches, 13 epoch,(0m 25s) is 0.007674
# Accuracy at 139 minibatches is 1.000000
# Average training loss at this epoch..minibatch..139..is 0.007674
# Validation loss after 139 passes is 0.621328
# Validation loss is higher than training loss at 139 is 0.621328 , stopping training!
# Average training loss at 139 is 0.189487
# Reached 14 epochs
# i 140
# Test accuracy: 0.875
# Max test accruacy: 0.9375
# Test aucroc: 0.9534412955465588
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 141 minibatches, 14 epoch,(0m 25s) is 0.003343
# Accuracy at 141 minibatches is 1.000000
# Average training loss at this epoch..minibatch..141..is 0.003343
# Validation loss after 141 passes is 0.548336
# Validation loss is higher than training loss at 141 is 0.548336 , stopping training!
# Average training loss at 141 is 0.188021
# Loss at 142 minibatches, 14 epoch,(0m 26s) is 0.002286
# Accuracy at 142 minibatches is 1.000000
# Average training loss at this epoch..minibatch..142..is 0.002286
# Validation loss after 142 passes is 0.711649
# Validation loss is higher than training loss at 142 is 0.711649 , stopping training!
# Average training loss at 142 is 0.186562
# Loss at 143 minibatches, 14 epoch,(0m 26s) is 0.001741
# Accuracy at 143 minibatches is 1.000000
# Average training loss at this epoch..minibatch..143..is 0.001741
# Validation loss after 143 passes is 0.733710
# Validation loss is higher than training loss at 143 is 0.733710 , stopping training!
# Average training loss at 143 is 0.185121
# Loss at 144 minibatches, 14 epoch,(0m 26s) is 0.001559
# Accuracy at 144 minibatches is 1.000000
# Average training loss at this epoch..minibatch..144..is 0.001559
# Validation loss after 144 passes is 0.557443
# Validation loss is higher than training loss at 144 is 0.557443 , stopping training!
# Average training loss at 144 is 0.183705
# Loss at 145 minibatches, 14 epoch,(0m 26s) is 0.001437
# Accuracy at 145 minibatches is 1.000000
# Average training loss at this epoch..minibatch..145..is 0.001437
# Validation loss after 145 passes is 0.546302
# Validation loss is higher than training loss at 145 is 0.546302 , stopping training!
# Average training loss at 145 is 0.182310
# Loss at 146 minibatches, 14 epoch,(0m 26s) is 0.001418
# Accuracy at 146 minibatches is 1.000000
# Average training loss at this epoch..minibatch..146..is 0.001418
# Validation loss after 146 passes is 0.617026
# Validation loss is higher than training loss at 146 is 0.617026 , stopping training!
# Average training loss at 146 is 0.180939
# Loss at 147 minibatches, 14 epoch,(0m 26s) is 0.001369
# Accuracy at 147 minibatches is 1.000000
# Average training loss at this epoch..minibatch..147..is 0.001369
# Validation loss after 147 passes is 0.563168
# Validation loss is higher than training loss at 147 is 0.563168 , stopping training!
# Average training loss at 147 is 0.179586
# Loss at 148 minibatches, 14 epoch,(0m 27s) is 0.001290
# Accuracy at 148 minibatches is 1.000000
# Average training loss at this epoch..minibatch..148..is 0.001290
# Validation loss after 148 passes is 0.469949
# Validation loss is higher than training loss at 148 is 0.469949 , stopping training!
# Average training loss at 148 is 0.178251
# Loss at 149 minibatches, 14 epoch,(0m 27s) is 0.001253
# Accuracy at 149 minibatches is 1.000000
# Average training loss at this epoch..minibatch..149..is 0.001253
# Validation loss after 149 passes is 0.633176
# Validation loss is higher than training loss at 149 is 0.633176 , stopping training!
# Average training loss at 149 is 0.176938
# Reached 15 epochs
# i 150
# Test accuracy: 0.890625
# Max test accruacy: 0.9375
# Test aucroc: 0.9523809523809523
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 151 minibatches, 15 epoch,(0m 27s) is 0.000601
# Accuracy at 151 minibatches is 1.000000
# Average training loss at this epoch..minibatch..151..is 0.000601
# Validation loss after 151 passes is 0.633362
# Validation loss is higher than training loss at 151 is 0.633362 , stopping training!
# Average training loss at 151 is 0.175642
# Loss at 152 minibatches, 15 epoch,(0m 27s) is 0.000711
# Accuracy at 152 minibatches is 1.000000
# Average training loss at this epoch..minibatch..152..is 0.000711
# Validation loss after 152 passes is 0.650092
# Validation loss is higher than training loss at 152 is 0.650092 , stopping training!
# Average training loss at 152 is 0.174365
# Loss at 153 minibatches, 15 epoch,(0m 28s) is 0.000783
# Accuracy at 153 minibatches is 1.000000
# Average training loss at this epoch..minibatch..153..is 0.000783
# Validation loss after 153 passes is 0.724688
# Validation loss is higher than training loss at 153 is 0.724688 , stopping training!
# Average training loss at 153 is 0.173109
# Loss at 154 minibatches, 15 epoch,(0m 28s) is 0.000930
# Accuracy at 154 minibatches is 1.000000
# Average training loss at this epoch..minibatch..154..is 0.000930
# Validation loss after 154 passes is 0.638227
# Validation loss is higher than training loss at 154 is 0.638227 , stopping training!
# Average training loss at 154 is 0.171873
# Loss at 155 minibatches, 15 epoch,(0m 28s) is 0.000916
# Accuracy at 155 minibatches is 1.000000
# Average training loss at this epoch..minibatch..155..is 0.000916
# Validation loss after 155 passes is 0.727610
# Validation loss is higher than training loss at 155 is 0.727610 , stopping training!
# Average training loss at 155 is 0.170652
# Loss at 156 minibatches, 15 epoch,(0m 28s) is 0.000893
# Accuracy at 156 minibatches is 1.000000
# Average training loss at this epoch..minibatch..156..is 0.000893
# Validation loss after 156 passes is 0.728396
# Validation loss is higher than training loss at 156 is 0.728396 , stopping training!
# Average training loss at 156 is 0.169447
# Loss at 157 minibatches, 15 epoch,(0m 28s) is 0.000894
# Accuracy at 157 minibatches is 1.000000
# Average training loss at this epoch..minibatch..157..is 0.000894
# Validation loss after 157 passes is 0.799799
# Validation loss is higher than training loss at 157 is 0.799799 , stopping training!
# Average training loss at 157 is 0.168260
# Loss at 158 minibatches, 15 epoch,(0m 29s) is 0.000927
# Accuracy at 158 minibatches is 1.000000
# Average training loss at this epoch..minibatch..158..is 0.000927
# Validation loss after 158 passes is 0.803368
# Validation loss is higher than training loss at 158 is 0.803368 , stopping training!
# Average training loss at 158 is 0.167091
# Loss at 159 minibatches, 15 epoch,(0m 29s) is 0.000898
# Accuracy at 159 minibatches is 1.000000
# Average training loss at this epoch..minibatch..159..is 0.000898
# Validation loss after 159 passes is 0.806139
# Validation loss is higher than training loss at 159 is 0.806139 , stopping training!
# Average training loss at 159 is 0.165936
# Reached 16 epochs
# i 160
# Test accuracy: 0.875
# Max test accruacy: 0.9375
# Test aucroc: 0.9487179487179488
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 161 minibatches, 16 epoch,(0m 29s) is 0.000967
# Accuracy at 161 minibatches is 1.000000
# Average training loss at this epoch..minibatch..161..is 0.000967
# Validation loss after 161 passes is 0.731761
# Validation loss is higher than training loss at 161 is 0.731761 , stopping training!
# Average training loss at 161 is 0.164798
# Loss at 162 minibatches, 16 epoch,(0m 29s) is 0.000811
# Accuracy at 162 minibatches is 1.000000
# Average training loss at this epoch..minibatch..162..is 0.000811
# Validation loss after 162 passes is 0.722599
# Validation loss is higher than training loss at 162 is 0.722599 , stopping training!
# Average training loss at 162 is 0.163674
# Loss at 163 minibatches, 16 epoch,(0m 30s) is 0.000825
# Accuracy at 163 minibatches is 1.000000
# Average training loss at this epoch..minibatch..163..is 0.000825
# Validation loss after 163 passes is 0.687654
# Validation loss is higher than training loss at 163 is 0.687654 , stopping training!
# Average training loss at 163 is 0.162566
# Loss at 164 minibatches, 16 epoch,(0m 30s) is 0.000872
# Accuracy at 164 minibatches is 1.000000
# Average training loss at this epoch..minibatch..164..is 0.000872
# Validation loss after 164 passes is 0.654094
# Validation loss is higher than training loss at 164 is 0.654094 , stopping training!
# Average training loss at 164 is 0.161474
# Loss at 165 minibatches, 16 epoch,(0m 30s) is 0.000814
# Accuracy at 165 minibatches is 1.000000
# Average training loss at this epoch..minibatch..165..is 0.000814
# Validation loss after 165 passes is 0.691897
# Validation loss is higher than training loss at 165 is 0.691897 , stopping training!
# Average training loss at 165 is 0.160395
# Loss at 166 minibatches, 16 epoch,(0m 30s) is 0.000739
# Accuracy at 166 minibatches is 1.000000
# Average training loss at this epoch..minibatch..166..is 0.000739
# Validation loss after 166 passes is 0.654944
# Validation loss is higher than training loss at 166 is 0.654944 , stopping training!
# Average training loss at 166 is 0.159328
# Loss at 167 minibatches, 16 epoch,(0m 30s) is 0.000743
# Accuracy at 167 minibatches is 1.000000
# Average training loss at this epoch..minibatch..167..is 0.000743
# Validation loss after 167 passes is 0.820938
# Validation loss is higher than training loss at 167 is 0.820938 , stopping training!
# Average training loss at 167 is 0.158278
# Loss at 168 minibatches, 16 epoch,(0m 30s) is 0.000694
# Accuracy at 168 minibatches is 1.000000
# Average training loss at this epoch..minibatch..168..is 0.000694
# Validation loss after 168 passes is 0.745762
# Validation loss is higher than training loss at 168 is 0.745762 , stopping training!
# Average training loss at 168 is 0.157239
# Loss at 169 minibatches, 16 epoch,(0m 31s) is 0.000683
# Accuracy at 169 minibatches is 1.000000
# Average training loss at this epoch..minibatch..169..is 0.000683
# Validation loss after 169 passes is 0.658362
# Validation loss is higher than training loss at 169 is 0.658362 , stopping training!
# Average training loss at 169 is 0.156215
# Reached 17 epochs
# i 170
# Test accuracy: 0.875
# Max test accruacy: 0.9375
# Test aucroc: 0.954954954954955
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 171 minibatches, 17 epoch,(0m 31s) is 0.000593
# Accuracy at 171 minibatches is 1.000000
# Average training loss at this epoch..minibatch..171..is 0.000593
# Validation loss after 171 passes is 0.750100
# Validation loss is higher than training loss at 171 is 0.750100 , stopping training!
# Average training loss at 171 is 0.155204
# Loss at 172 minibatches, 17 epoch,(0m 31s) is 0.000611
# Accuracy at 172 minibatches is 1.000000
# Average training loss at this epoch..minibatch..172..is 0.000611
# Validation loss after 172 passes is 0.751005
# Validation loss is higher than training loss at 172 is 0.751005 , stopping training!
# Average training loss at 172 is 0.154207
# Loss at 173 minibatches, 17 epoch,(0m 31s) is 0.000654
# Accuracy at 173 minibatches is 1.000000
# Average training loss at this epoch..minibatch..173..is 0.000654
# Validation loss after 173 passes is 0.829649
# Validation loss is higher than training loss at 173 is 0.829649 , stopping training!
# Average training loss at 173 is 0.153223
# Loss at 174 minibatches, 17 epoch,(0m 32s) is 0.000615
# Accuracy at 174 minibatches is 1.000000
# Average training loss at this epoch..minibatch..174..is 0.000615
# Validation loss after 174 passes is 0.738830
# Validation loss is higher than training loss at 174 is 0.738830 , stopping training!
# Average training loss at 174 is 0.152251
# Loss at 175 minibatches, 17 epoch,(0m 32s) is 0.000582
# Accuracy at 175 minibatches is 1.000000
# Average training loss at this epoch..minibatch..175..is 0.000582
# Validation loss after 175 passes is 0.744448
# Validation loss is higher than training loss at 175 is 0.744448 , stopping training!
# Average training loss at 175 is 0.151290
# Loss at 176 minibatches, 17 epoch,(0m 32s) is 0.000555
# Accuracy at 176 minibatches is 1.000000
# Average training loss at this epoch..minibatch..176..is 0.000555
# Validation loss after 176 passes is 0.730415
# Validation loss is higher than training loss at 176 is 0.730415 , stopping training!
# Average training loss at 176 is 0.150341
# Loss at 177 minibatches, 17 epoch,(0m 32s) is 0.000557
# Accuracy at 177 minibatches is 1.000000
# Average training loss at this epoch..minibatch..177..is 0.000557
# Validation loss after 177 passes is 0.758119
# Validation loss is higher than training loss at 177 is 0.758119 , stopping training!
# Average training loss at 177 is 0.149405
# Loss at 178 minibatches, 17 epoch,(0m 32s) is 0.000552
# Accuracy at 178 minibatches is 1.000000
# Average training loss at this epoch..minibatch..178..is 0.000552
# Validation loss after 178 passes is 0.749071
# Validation loss is higher than training loss at 178 is 0.749071 , stopping training!
# Average training loss at 178 is 0.148480
# Loss at 179 minibatches, 17 epoch,(0m 32s) is 0.000564
# Accuracy at 179 minibatches is 1.000000
# Average training loss at this epoch..minibatch..179..is 0.000564
# Validation loss after 179 passes is 0.745264
# Validation loss is higher than training loss at 179 is 0.745264 , stopping training!
# Average training loss at 179 is 0.147568
# Reached 18 epochs
# i 180
# Test accuracy: 0.890625
# Max test accruacy: 0.9375
# Test aucroc: 0.963076923076923
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 181 minibatches, 18 epoch,(0m 33s) is 0.000331
# Accuracy at 181 minibatches is 1.000000
# Average training loss at this epoch..minibatch..181..is 0.000331
# Validation loss after 181 passes is 0.751303
# Validation loss is higher than training loss at 181 is 0.751303 , stopping training!
# Average training loss at 181 is 0.146664
# Loss at 182 minibatches, 18 epoch,(0m 33s) is 0.000519
# Accuracy at 182 minibatches is 1.000000
# Average training loss at this epoch..minibatch..182..is 0.000519
# Validation loss after 182 passes is 0.714285
# Validation loss is higher than training loss at 182 is 0.714285 , stopping training!
# Average training loss at 182 is 0.145774
# Loss at 183 minibatches, 18 epoch,(0m 33s) is 0.000491
# Accuracy at 183 minibatches is 1.000000
# Average training loss at this epoch..minibatch..183..is 0.000491
# Validation loss after 183 passes is 0.842591
# Validation loss is higher than training loss at 183 is 0.842591 , stopping training!
# Average training loss at 183 is 0.144893
# Loss at 184 minibatches, 18 epoch,(0m 33s) is 0.000445
# Accuracy at 184 minibatches is 1.000000
# Average training loss at this epoch..minibatch..184..is 0.000445
# Validation loss after 184 passes is 0.844570
# Validation loss is higher than training loss at 184 is 0.844570 , stopping training!
# Average training loss at 184 is 0.144022
# Loss at 185 minibatches, 18 epoch,(0m 34s) is 0.000433
# Accuracy at 185 minibatches is 1.000000
# Average training loss at this epoch..minibatch..185..is 0.000433
# Validation loss after 185 passes is 0.753389
# Validation loss is higher than training loss at 185 is 0.753389 , stopping training!
# Average training loss at 185 is 0.143162
# Loss at 186 minibatches, 18 epoch,(0m 34s) is 0.000421
# Accuracy at 186 minibatches is 1.000000
# Average training loss at this epoch..minibatch..186..is 0.000421
# Validation loss after 186 passes is 0.719141
# Validation loss is higher than training loss at 186 is 0.719141 , stopping training!
# Average training loss at 186 is 0.142312
# Loss at 187 minibatches, 18 epoch,(0m 34s) is 0.000419
# Accuracy at 187 minibatches is 1.000000
# Average training loss at this epoch..minibatch..187..is 0.000419
# Validation loss after 187 passes is 0.540232
# Validation loss is higher than training loss at 187 is 0.540232 , stopping training!
# Average training loss at 187 is 0.141473
# Loss at 188 minibatches, 18 epoch,(0m 34s) is 0.000422
# Accuracy at 188 minibatches is 1.000000
# Average training loss at this epoch..minibatch..188..is 0.000422
# Validation loss after 188 passes is 0.848905
# Validation loss is higher than training loss at 188 is 0.848905 , stopping training!
# Average training loss at 188 is 0.140643
# Loss at 189 minibatches, 18 epoch,(0m 34s) is 0.000424
# Accuracy at 189 minibatches is 1.000000
# Average training loss at this epoch..minibatch..189..is 0.000424
# Validation loss after 189 passes is 0.772130
# Validation loss is higher than training loss at 189 is 0.772130 , stopping training!
# Average training loss at 189 is 0.139823
# Reached 19 epochs
# i 190
# Test accuracy: 0.875
# Max test accruacy: 0.9375
# Test aucroc: 0.946875
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 191 minibatches, 19 epoch,(0m 35s) is 0.000514
# Accuracy at 191 minibatches is 1.000000
# Average training loss at this epoch..minibatch..191..is 0.000514
# Validation loss after 191 passes is 0.851936
# Validation loss is higher than training loss at 191 is 0.851936 , stopping training!
# Average training loss at 191 is 0.139013
# Loss at 192 minibatches, 19 epoch,(0m 35s) is 0.000440
# Accuracy at 192 minibatches is 1.000000
# Average training loss at this epoch..minibatch..192..is 0.000440
# Validation loss after 192 passes is 0.691439
# Validation loss is higher than training loss at 192 is 0.691439 , stopping training!
# Average training loss at 192 is 0.138212
# Loss at 193 minibatches, 19 epoch,(0m 35s) is 0.000408
# Accuracy at 193 minibatches is 1.000000
# Average training loss at this epoch..minibatch..193..is 0.000408
# Validation loss after 193 passes is 0.768645
# Validation loss is higher than training loss at 193 is 0.768645 , stopping training!
# Average training loss at 193 is 0.137419
# Loss at 194 minibatches, 19 epoch,(0m 35s) is 0.000424
# Accuracy at 194 minibatches is 1.000000
# Average training loss at this epoch..minibatch..194..is 0.000424
# Validation loss after 194 passes is 0.558842
# Validation loss is higher than training loss at 194 is 0.558842 , stopping training!
# Average training loss at 194 is 0.136637
# Loss at 195 minibatches, 19 epoch,(0m 36s) is 0.000403
# Accuracy at 195 minibatches is 1.000000
# Average training loss at this epoch..minibatch..195..is 0.000403
# Validation loss after 195 passes is 0.770182
# Validation loss is higher than training loss at 195 is 0.770182 , stopping training!
# Average training loss at 195 is 0.135862
# Loss at 196 minibatches, 19 epoch,(0m 36s) is 0.000386
# Accuracy at 196 minibatches is 1.000000
# Average training loss at this epoch..minibatch..196..is 0.000386
# Validation loss after 196 passes is 0.738235
# Validation loss is higher than training loss at 196 is 0.738235 , stopping training!
# Average training loss at 196 is 0.135097
# Loss at 197 minibatches, 19 epoch,(0m 36s) is 0.000373
# Accuracy at 197 minibatches is 1.000000
# Average training loss at this epoch..minibatch..197..is 0.000373
# Validation loss after 197 passes is 0.672038
# Validation loss is higher than training loss at 197 is 0.672038 , stopping training!
# Average training loss at 197 is 0.134339
# Loss at 198 minibatches, 19 epoch,(0m 36s) is 0.000375
# Accuracy at 198 minibatches is 1.000000
# Average training loss at this epoch..minibatch..198..is 0.000375
# Validation loss after 198 passes is 0.656769
# Validation loss is higher than training loss at 198 is 0.656769 , stopping training!
# Average training loss at 198 is 0.133591
# Loss at 199 minibatches, 19 epoch,(0m 36s) is 0.000362
# Accuracy at 199 minibatches is 1.000000
# Average training loss at this epoch..minibatch..199..is 0.000362
# Validation loss after 199 passes is 0.635744
# Validation loss is higher than training loss at 199 is 0.635744 , stopping training!
# Average training loss at 199 is 0.132850
# Reached 20 epochs
# i 200
# Test accuracy: 0.875
# Max test accruacy: 0.9375
# Test aucroc: 0.945945945945946
# Max test aucroc: 0.9851190476190477
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0

# %%
#print(test_accuracy_full_batch(corpus.X_test, corpus.y_test, my_batch, word_attn, sent_attn))

# %%
#test_accuracy_full_batch(corpus.X_train, corpus.y_train, my_batch, word_attn, sent_attn)
