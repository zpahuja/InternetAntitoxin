# %%
import os
import torch
import numpy as np
import csv
import collections

class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = [] #index gives word
        self.idx2abv = [] #discrete feature: is index nazi abv
        self.idx2phrase = []
        self.idx2german = []
        self.idx2group = []
        self.pretrain_vec = [] # should match index order of words in dict.
        
        self.abvs = []
        self.phrases = [] #only 1-word phrases + echo
        self.german = [] #only 1-word german 
        self.groups = [] #only 1-word groups
        
        self.load_nazi_features()
    
    def load_nazi_features(self):
        with open('abbreviations.txt', 'r', encoding='utf-8') as f:
            for line in f:
                words = line.split()
                #print(words[0].lower())
                self.abvs.append(words[0].lower())
        self.phrases.append('(((')
        self.phrases.append(')))')
        '''
        with open('phrases.txt', 'r', encoding='utf-8') as f:
            for line in f:
                words = line.split()
                if len(words)==1:
                    self.phrases.append(words[0].lower())
        
        with open('german.txt', 'r', encoding='utf-8') as f:
            for line in f:
                words = line.split()
                if len(words)==1:
                    self.german.append(words[0].lower())
        with open('groups.txt', 'r', encoding='utf-8') as f:
            for line in f:
                words = line.split()
                if len(words)==1:
                    self.groups.append(words[0].lower())
        '''
    
    #just abbreviations for now
    #cause finding chunks means keeping track of last 6 words
    def find_nazi_features(self,word):#create lookup for discrete feature
        if word.lower() in self.abvs:
            #print("ding",word.lower())
            self.idx2abv.append([0.1]) #yes
        else:
            self.idx2abv.append([0]) #no
            
        #For subphrases
        found = False
        for i in self.phrases:
            if i in word.lower():
                #print("ding",word.lower())
                found = True
                break
                
        if found:
            self.idx2phrase.append([0.1])
        else:
            self.idx2phrase.append([0])
            
        '''
        #For subphrases
        found = False
        for i in self.german:
            if i in word.lower():
                #print("ding",word.lower())
                found = True
                break
                
        if found:
            self.idx2german.append([1])
        else:
            self.idx2german.append([0])
            
        #For subphrases
        found = False
        for i in self.groups:
            if i in word.lower():
                #print("ding",word.lower())
                found = True
                break
                
        if found:
            self.idx2group.append([1])
        else:
            self.idx2group.append([0])
        '''
            
        
    def add_word(self, word, ahead_six=None, vec=None):
        if vec is None:
            if word not in self.word2idx:
                self.idx2word.append(word)
                self.word2idx[word] = len(self.idx2word) - 1
                self.find_nazi_features(word)
        else:
            if word not in self.word2idx:
                self.pretrain_vec.append(vec)
                self.idx2word.append(word)
                self.word2idx[word] = len(self.idx2word) - 1
                self.find_nazi_features(word)
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)


class Corpus(object):
    def __init__(self, path, language):
        self.dictionary = Dictionary()
        if language is not None:
            self.pretrained = self.add_pretrained(os.path.join('', 'wiki.' + language + '.vec'))
        #self.trainid, self.trainlab, self.trainidx = self.tokenize_by_user(os.path.join(path, 'train.csv'),True)
        #self.validid, self.validlab, self.valididx = self.tokenize_by_user(os.path.join(path, 'valid.csv'),False)
        #self.testid, self.testlab, self.testidx = self.tokenize_by_user(os.path.join(path, 'test.csv'),False)
        self.X_train, self.y_train = self.tokenize(os.path.join('', 'train.csv'),True)
        #self.X_valid, self.y_valid = self.tokenize(os.path.join(path, 'valid.csv'),False)
        self.X_test, self.y_test = self.tokenize(os.path.join('', 'test.csv'),False)
        

    def add_pretrained(self, path):
        assert os.path.exists(path)

        # Add words with pretrained vectors to the dictionary
        # might be weird because no eos was added?
        with open(path, 'r', encoding='utf-8') as f:
            tokens = 0
            for line in f:
                words = line.split()
                if len(words) == 2: #first line
                    continue
                word = words[0]
                vec = words[1:]
                if len(vec) != 300:
                    continue #this skips the space embedding
                #vec = np.array(list(map(float, vec)))
                vec = list(map(float,vec))
                tokens += 1
                
                self.dictionary.add_word(word, vec)
    def tokenize(self, path, header):
        """Tokenizes a text file."""
        assert os.path.exists(path)
        # Add words to the dictionary
        with open(path, 'r', encoding='utf-8') as f:
            reader = csv.reader(f)
            tokens = 0
            prev = None
            if header:
                first = True
            else:
                first = False
            tweet_count = 0
            user_idx = -1
            for row in reader:
                if first:
                    first = False
                    continue
                if len(row) is not 6:
                    continue
                
                tweet = row[0]
                label = row[1]
                if not label.isdigit():
                    continue
                extra = row[2:5] #bio, tweet pic, profile pic, user id
                if row[2] != prev: #new user
                    prev = row[2]
                    tweet_count = 0
                    user_idx += 1
                    words = row[2].split() #add bio
                    for word in words:
                        self.dictionary.add_word(word)

                words = tweet.split()
                tokens += len(words)
                for word in words:
                    self.dictionary.add_word(word)

        # Tokenize file content
        with open(path, 'r', encoding='utf-8') as f:
            x = np.zeros(user_idx+1,dtype='object')
            y = np.zeros(user_idx+1,dtype='int')
            #ids = torch.LongTensor(tokens)
            #idxs = torch.LongTensor(user_idx+1)
            #labels = torch.LongTensor(user_idx+1)
            #print(user_idx+1)
            token = 0
            prev = None

            reader = csv.reader(f)
            if header:
                first = True
            else:
                first = False
            user_idx = -1
            for row in reader:
                if first:
                    first = False
                    continue
                if len(row) is not 6:
                    continue
                
                tweet = row[0]
                label = row[1]
                if not label.isdigit():
                    continue
                extra = row[2:5] #bio, tweet pic, profile pic, user id
                if row[2] != prev:
                    tweet_idx = -1
                    user_idx += 1
                    prev = row[2]
                    y[user_idx] = int(label)
                    x[user_idx] = []
                    #print(token, "NEW USER")
                    #idxs[user_idx] = token
                    x[user_idx].append([])
                    words = row[2].split() #take the bio as the 'first tweet'
                    tweet_idx+=1
                    for word in words:
                        x[user_idx][0].append(self.dictionary.word2idx[word])
                

                words = tweet.split()
                token = 0
                tweet_idx+=1
                if tweet_idx >=21:
                    #print(tweet_idx)
                    continue
                x[user_idx].append([])
                for word in words:
                    x[user_idx][tweet_idx].append(self.dictionary.word2idx[word])
                    token+=1
                

        return x, y

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F

#attention functions

def batch_matmul_bias(seq, weight, bias, nonlinearity=''):
    s = None
    bias_dim = bias.size()
    for i in range(seq.size(0)):
        _s = torch.mm(seq[i], weight) 
        _s_bias = _s + bias.expand(bias_dim[0], _s.size()[0]).transpose(0,1)
        if(nonlinearity=='tanh'):
            _s_bias = torch.tanh(_s_bias)
        _s_bias = _s_bias.unsqueeze(0)
        if(s is None):
            s = _s_bias
        else:
            s = torch.cat((s,_s_bias),0)
    return s.squeeze()

def batch_matmul(seq, weight, nonlinearity=''):
    s = None
    for i in range(seq.size(0)):
        _s = torch.mm(seq[i], weight)
        if(nonlinearity=='tanh'):
            _s = torch.tanh(_s)
        _s = _s.unsqueeze(0)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)
    return s.squeeze()

def attention_mul(rnn_outputs, att_weights):
    attn_vectors = None
    for i in range(rnn_outputs.size(0)):
        h_i = rnn_outputs[i]
        a_i = att_weights[i].unsqueeze(1).expand_as(h_i)
        h_i = a_i * h_i
        h_i = h_i.unsqueeze(0)
        if(attn_vectors is None):
            attn_vectors = h_i
        else:
            attn_vectors = torch.cat((attn_vectors,h_i),0)
    return torch.sum(attn_vectors, 0).unsqueeze(0)

'''
def batch_matmul_bias(seq, weight, bias, nonlinearity=''):
    s = None
    bias_dim = bias.size()
    for i in range(seq.size(0)):
        _s = torch.mm(seq[i], weight) 
        _s_bias = _s + bias.expand(bias_dim[0], _s.size()[0]).transpose(0,1)
        if(nonlinearity=='tanh'):
            _s_bias = torch.tanh(_s_bias)
        _s_bias = _s_bias.unsqueeze(0)
        if(s is None):
            s = _s_bias
        else:
            s = torch.cat((s,_s_bias),0)
    return s.squeeze()
    
def batch_matmul(seq, weight, nonlinearity=''):
    s = None
    for i in range(seq.size(0)):
        _s = torch.mm(seq[i], weight)
        if(nonlinearity=='tanh'):
            _s = torch.tanh(_s)
        _s = _s.unsqueeze(0)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)
    return s.squeeze()

def attention_mul(self, rnn_outputs, att_weights):
    attn_vectors = None
    for i in range(rnn_outputs.size(0)):
        h_i = rnn_outputs[i]
        a_i = att_weights[i].unsqueeze(1).expand_as(h_i)
        h_i = a_i * h_i
        h_i = h_i.unsqueeze(0)
        if(attn_vectors is None):
            attn_vectors = h_i
        else:
            attn_vectors = torch.cat((attn_vectors,h_i),0)
    return torch.sum(attn_vectors, 0).unsqueeze(0)
'''
class AttentionWordRNN(nn.Module):
    
    
    def __init__(self, embeds, abvs, phrases, german, groups, batch_size,
                 num_tokens, embed_size, word_gru_hidden, dropout, bidirectional= True):        
        
        super(AttentionWordRNN, self).__init__()
        
        self.batch_size = batch_size
        self.num_tokens = num_tokens
        self.embed_size = embed_size #add abv feature size on
        self.word_gru_hidden = word_gru_hidden
        self.bidirectional = bidirectional
        self.drop = nn.Dropout(dropout)

        
        
        self.lookup = nn.Embedding(num_tokens, 300)
        self.lookup_abv = nn.Embedding(num_tokens, 1)
        self.lookup_phr = nn.Embedding(num_tokens, 1)
        #self.lookup_ger = nn.Embedding(num_tokens, 1)
        #self.lookup_gro = nn.Embedding(num_tokens, 1)
        #self.abvs = abvs #doesn't need gradient, it's static/discrete

        #init lookup table
        #print(len(embeds),embeds[0])
        #print(len(abvs),abvs[0])

        
        initrange = 0.1

        k = len(embeds) # the first k indices are pretrained. the rest are unknown
        
        if k is not 0:
            first = np.array(embeds)
            second = np.random.uniform(-initrange,initrange,size=(num_tokens-k,300))
            self.lookup.weight.data.copy_(torch.from_numpy(np.concatenate((first,second),axis=0)))
        else:
            self.lookup.weight.data.uniform_(-initrange, initrange)
        self.lookup_abv.weight.requires_grad=False
        self.lookup_abv.weight.data.copy_(torch.from_numpy(np.array(abvs)))
        self.lookup_phr.weight.requires_grad=False
        self.lookup_phr.weight.data.copy_(torch.from_numpy(np.array(phrases)))
        #self.lookup_ger.weight.requires_grad=False
        #self.lookup_ger.weight.data.copy_(torch.from_numpy(np.array(german)))
        #self.lookup_gro.weight.requires_grad=False
        #self.lookup_gro.weight.data.copy_(torch.from_numpy(np.array(groups)))
        

        if bidirectional == True:
            self.word_gru = nn.GRU(embed_size, word_gru_hidden, bidirectional= True)
            self.weight_W_word = nn.Parameter(torch.Tensor(2* word_gru_hidden,2*word_gru_hidden))
            self.bias_word = nn.Parameter(torch.Tensor(2* word_gru_hidden,1))
            self.weight_proj_word = nn.Parameter(torch.Tensor(2*word_gru_hidden, 1))
        else:
            self.word_gru = nn.GRU(embed_size, word_gru_hidden, bidirectional= False)
            self.weight_W_word = nn.Parameter(torch.Tensor(word_gru_hidden, word_gru_hidden))
            self.bias_word = nn.Parameter(torch.Tensor(word_gru_hidden,1))
            self.weight_proj_word = nn.Parameter(torch.Tensor(word_gru_hidden, 1))
            
        self.softmax_word = nn.Softmax()
        #self.word_gru.data.uniform_(-initrange,initrange)
        self.weight_W_word.data.uniform_(-initrange, initrange)
        self.weight_proj_word.data.uniform_(-initrange,initrange)
        self.bias_word.data.uniform_(-initrange,initrange)

        
        
    def forward(self, embed, state_word):
        # embeddings
        #print(embed)
        embedded = self.drop(self.lookup(embed))
        abv_feature = self.lookup_abv(embed)
        phr_feature = self.lookup_phr(embed)
        #ger_feature = self.lookup_ger(embed)
        #gro_feature = self.lookup_gro(embed)
        #print(len(embedded), len(abv_feature))
        #embedded = torch.cat((embedded,abv_feature,phr_feature,ger_feature,gro_feature),dim=2)
        embedded = torch.cat((embedded,abv_feature,phr_feature),dim=2)
        # word level gru
        #state_word = self.drop(state_word) #idk
        output_word, state_word = self.word_gru(embedded, state_word)
        state_word = self.drop(state_word) #idk
        output_word = self.drop(output_word)
#         print output_word.size()
        word_squish = self.drop(batch_matmul_bias(output_word, self.weight_W_word,self.bias_word, nonlinearity='tanh'))
        word_attn = self.drop(batch_matmul(word_squish, self.weight_proj_word))
        word_attn_norm = self.drop(self.softmax_word(word_attn.transpose(1,0)))
        word_attn_vectors = self.drop(attention_mul(output_word, word_attn_norm.transpose(1,0)))
        return word_attn_vectors, state_word, word_attn_norm
    
    def init_hidden(self):
        if self.bidirectional == True:
            return Variable(torch.zeros(2, self.batch_size, self.word_gru_hidden))
        else:
            return Variable(torch.zeros(1, self.batch_size, self.word_gru_hidden))

class AttentionSentRNN(nn.Module):
    
    
    def __init__(self, batch_size, sent_gru_hidden, word_gru_hidden, n_classes, dropout, bidirectional= True):        
        
        super(AttentionSentRNN, self).__init__()
        
        self.batch_size = batch_size
        self.sent_gru_hidden = sent_gru_hidden
        self.n_classes = n_classes
        self.word_gru_hidden = word_gru_hidden
        self.bidirectional = bidirectional
        
        self.drop = nn.Dropout(dropout)

        initrange = 0.1
        
        
        if bidirectional == True:
            self.sent_gru = nn.GRU(2 * word_gru_hidden, sent_gru_hidden, bidirectional= True)        
            self.weight_W_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden ,2* sent_gru_hidden))
            self.bias_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden,1))
            self.weight_proj_sent = nn.Parameter(torch.Tensor(2* sent_gru_hidden, 1))
            self.final_linear = nn.Linear(2* sent_gru_hidden, n_classes)
        else:
            self.sent_gru = nn.GRU(word_gru_hidden, sent_gru_hidden, bidirectional= True)        
            self.weight_W_sent = nn.Parameter(torch.Tensor(sent_gru_hidden ,sent_gru_hidden))
            self.bias_sent = nn.Parameter(torch.Tensor(sent_gru_hidden,1))
            self.weight_proj_sent = nn.Parameter(torch.Tensor(sent_gru_hidden, 1))
            self.final_linear = nn.Linear(sent_gru_hidden, n_classes)
        self.softmax_sent = nn.Softmax()
        self.final_softmax = nn.Softmax()
        self.bias_sent.data.uniform_(-initrange, initrange)
        #self.sent_gru.data.uniform_(-initrange,initrange)
        self.weight_W_sent.data.uniform_(-initrange, initrange)
        self.weight_proj_sent.data.uniform_(-initrange,initrange)
        
        
    def forward(self, word_attention_vectors, state_sent):
        #MANUALLY DROPOUT THE GRU
        #state_word = self.drop(state_sent)
        output_sent, state_sent = self.sent_gru(word_attention_vectors, state_sent)   
        state_word = self.drop(state_sent)
        output_sent = self.drop(output_sent)
        sent_squish = self.drop(batch_matmul_bias(output_sent, self.weight_W_sent,self.bias_sent, nonlinearity='tanh'))
        sent_attn = self.drop(batch_matmul(sent_squish, self.weight_proj_sent))
        sent_attn_norm = self.drop(self.softmax_sent(sent_attn.transpose(1,0)))
        sent_attn_vectors = self.drop(attention_mul(output_sent, sent_attn_norm.transpose(1,0)))    
        # final classifier
        final_map = self.final_linear(sent_attn_vectors.squeeze(0))
        return F.log_softmax(final_map), state_sent, sent_attn_norm
    
    def init_hidden(self):
        if self.bidirectional == True:
            return Variable(torch.zeros(2, self.batch_size, self.sent_gru_hidden))
        else:
            return Variable(torch.zeros(1, self.batch_size, self.sent_gru_hidden))

# %%
#import model
#import data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import sklearn.metrics

dropout=0
my_batch=64
lang='en'
datapath = './data/'+lang
corpus = Corpus(datapath, lang)
ntokens = len(corpus.dictionary)
pretrain = corpus.dictionary.pretrain_vec
idx2abv = corpus.dictionary.idx2abv
idx2phrase = corpus.dictionary.idx2phrase
#idx2german = corpus.dictionary.idx2german
#idx2group = corpus.dictionary.idx2group

word_attn = AttentionWordRNN(embeds=pretrain, abvs=idx2abv, phrases=idx2phrase, german=None, groups=None,
                             batch_size=my_batch, num_tokens=ntokens, embed_size=300+2, 
                             word_gru_hidden=100, dropout=dropout, bidirectional= True)

sent_attn = AttentionSentRNN(batch_size=my_batch, sent_gru_hidden=100, word_gru_hidden=100, 
                             n_classes=2, dropout=dropout, bidirectional= True)

def train_data(mini_batch, targets, word_attn_model, sent_attn_model, word_optimizer, sent_optimizer, criterion):
    state_word = word_attn_model.init_hidden().cuda()
    state_sent = sent_attn_model.init_hidden().cuda()
    max_sents, batch_size, max_tokens = mini_batch.size()
    word_optimizer.zero_grad()
    sent_optimizer.zero_grad()
    s = None
    for i in range(max_sents):
        #torch.cuda.empty_cache()
        _s, state_word, _ = word_attn_model(mini_batch[i,:,:].transpose(0,1), state_word)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)            
    y_pred, state_sent, _ = sent_attn_model(s, state_sent)
    loss = criterion(y_pred.cuda(), targets)

    state_word = None
    state_sent = None
    max_sents = None
    batch_size = None
    max_tokens = None 
    mini_batch = None
    torch.cuda.empty_cache()
    loss.backward()
    
    word_optimizer.step()
    sent_optimizer.step()
    
    return loss.data.item()



def get_predictions(val_tokens, word_attn_model, sent_attn_model):
    max_sents, batch_size, max_tokens = val_tokens.size()
    state_word = word_attn_model.init_hidden().cuda()
    state_sent = sent_attn_model.init_hidden().cuda()
    s = None
    for i in range(max_sents):
        _s, state_word, _ = word_attn_model(val_tokens[i,:,:].transpose(0,1), state_word)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)            
    y_pred, state_sent, _ = sent_attn_model(s, state_sent)    
    return y_pred



#learning_rate = 0.001
#momentum = 0.9
#word_optimizer = torch.optim.SGD(word_attn.parameters(), lr=learning_rate, momentum= momentum)
#sent_optimizer = torch.optim.SGD(sent_attn.parameters(), lr=learning_rate, momentum= momentum)
#word_optimizer = torch.optim.Adam(word_attn.parameters())
word_optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, word_attn.parameters()))
sent_optimizer = torch.optim.Adam(sent_attn.parameters())
criterion = nn.NLLLoss()

word_attn.cuda()
sent_attn.cuda()



def pad_batch(mini_batch):
    mini_batch_size = len(mini_batch)
    max_sent_len = int(np.mean([len(x) for x in mini_batch]))
    max_token_len = int(np.mean([len(val) for sublist in mini_batch for val in sublist]))
    main_matrix = np.zeros((mini_batch_size, max_sent_len, max_token_len), dtype= np.int)
    for i in range(main_matrix.shape[0]):
        for j in range(main_matrix.shape[1]):
            for k in range(main_matrix.shape[2]):
                try:
                    main_matrix[i,j,k] = mini_batch[i][j][k]
                except IndexError:
                    pass
    #return Variable(torch.from_numpy(main_matrix).transpose(0,1))
    return Variable(torch.LongTensor(main_matrix).transpose(0,1))



def test_accuracy_mini_batch(tokens, labels, word_attn, sent_attn):
    y_pred = get_predictions(tokens, word_attn, sent_attn)
    _, y_pred = torch.max(y_pred, 1)
    correct = np.ndarray.flatten(y_pred.data.cpu().numpy())
    labels = np.ndarray.flatten(labels.data.cpu().numpy())
    num_correct = sum(correct == labels)
    return float(num_correct) / len(correct)

def test_accuracy_full_batch(tokens, labels, mini_batch_size, word_attn, sent_attn):
    p = []
    p_nonlinear = []
    l = []
    g = gen_minibatch(tokens, labels, mini_batch_size)
    for token, label in g:
        y_pred = get_predictions(token.cuda(), word_attn, sent_attn)
        #print("BEFORE",y_pred)
        p_nonlinear.append(np.ndarray.flatten(y_pred[:,1].data.cpu().numpy()))
        _, y_pred = torch.max(y_pred, 1)
        #print("AFTER",y_pred)
        p.append(np.ndarray.flatten(y_pred.data.cpu().numpy()))
        l.append(np.ndarray.flatten(label.data.cpu().numpy()))
    p = [item for sublist in p for item in sublist]
    l = [item for sublist in l for item in sublist]
    p_nonlinear = [np.exp(item) for sublist in p_nonlinear for item in sublist]
    p = np.array(p)
    l = np.array(l)
    #print("TOKEN LEN",len(tokens))
    #print("NONLINEAR",p_nonlinear)
    #print("PREDICT",p)
    #print("LABEL",l)
    num_correct = sum(p == l)
    return float(num_correct)/ len(p), sklearn.metrics.roc_auc_score(l, p_nonlinear)

def test_data(mini_batch, targets, word_attn_model, sent_attn_model):    
    state_word = word_attn_model.init_hidden().cuda()
    state_sent = sent_attn_model.init_hidden().cuda()
    max_sents, batch_size, max_tokens = mini_batch.size()
    s = None
    for i in range(max_sents):
        _s, state_word, _ = word_attn_model(mini_batch[i,:,:].transpose(0,1), state_word)
        if(s is None):
            s = _s
        else:
            s = torch.cat((s,_s),0)            
    y_pred, state_sent,_ = sent_attn_model(s, state_sent)
    loss = criterion(y_pred.cuda(), targets)     
    return loss.data.item()

def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert inputs.shape[0] == targets.shape[0]
    if shuffle:
        indices = np.arange(inputs.shape[0])
        np.random.shuffle(indices)
    #print(inputs.shape[0] - batchsize+1, batchsize, "HOO")
    for start_idx in range(0, inputs.shape[0] - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]



def gen_minibatch(tokens, labels, mini_batch_size, shuffle= True):
    for token, label in iterate_minibatches(tokens, labels, mini_batch_size, shuffle= shuffle):
        token = pad_batch(token)
        yield token.cuda(), Variable(torch.LongTensor(label), requires_grad= False).cuda()

def check_val_loss(val_tokens, val_labels, mini_batch_size, word_attn_model, sent_attn_model):
    val_loss = []
    for token, label in iterate_minibatches(val_tokens, val_labels, mini_batch_size, shuffle= True):
        val_loss.append(test_data(pad_batch(token).cuda(), Variable(torch.LongTensor(label), requires_grad= False).cuda(), 
                                  word_attn_model, sent_attn_model))
    return np.mean(val_loss)

import time
import math

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def train_early_stopping(mini_batch_size, X_train, y_train, X_test, y_test, word_attn_model, sent_attn_model, 
                         word_attn_optimiser, sent_attn_optimiser, loss_criterion, num_epoch, 
                         print_val_loss_every = 1000, print_loss_every = 50):
    #for i in word_attn_model.parameters():
        #print(i.data, "PARAM")
    max_eval_acc = 0
    max_train_acc = 0
    max_eval_aucroc = 0
    max_train_aucroc = 0
    word_attn_model.train()
    sent_attn_model.train()
    start = time.time()
    loss_full = []
    loss_epoch = []
    accuracy_epoch = []
    loss_smooth = []
    accuracy_full = []
    epoch_counter = 0
    g = gen_minibatch(X_train, y_train, mini_batch_size)
    for i in range(1, num_epoch + 1):
        try:
            word_attn_model.train()
            sent_attn_model.train()
            tokens, labels = next(g)
            loss = train_data(tokens, labels, word_attn_model, sent_attn_model, word_attn_optimiser, sent_attn_optimiser, loss_criterion)
            acc = test_accuracy_mini_batch(tokens, labels, word_attn_model, sent_attn_model)
            accuracy_full.append(acc)
            accuracy_epoch.append(acc)
            loss_full.append(loss)
            loss_epoch.append(loss)
            # print loss every n passes
            if i % print_loss_every == 0:
                print('Loss at %d minibatches, %d epoch,(%s) is %f' %(i, epoch_counter, timeSince(start), np.mean(loss_epoch)))
                print('Accuracy at %d minibatches is %f' % (i, np.mean(accuracy_epoch)))
            # check validation loss every n passes
            if i % print_val_loss_every == 0:
                word_attn_model.eval()
                sent_attn_model.eval()
                val_loss = check_val_loss(X_test, y_test, mini_batch_size, word_attn_model, sent_attn_model)
                print('Average training loss at this epoch..minibatch..%d..is %f' % (i, np.mean(loss_epoch)))
                print('Validation loss after %d passes is %f' %(i, val_loss))
                if val_loss > np.mean(loss_full):
                    print('Validation loss is higher than training loss at %d is %f , stopping training!' % (i, val_loss))
                    print('Average training loss at %d is %f' % (i, np.mean(loss_full)))
        except StopIteration:
            epoch_counter += 1
            print('Reached %d epochs' % epoch_counter)
            print('i %d' % i)
            word_attn_model.eval()
            sent_attn_model.eval()
            acc, aucroc = test_accuracy_full_batch(corpus.X_test, corpus.y_test, my_batch, word_attn, sent_attn)
            if acc>max_eval_acc:
                max_eval_acc = acc
            if aucroc>max_eval_aucroc:
                max_eval_aucroc = aucroc
            print("Test accuracy:",acc)
            print("Max test accruacy:",max_eval_acc)
            print("Test aucroc:",aucroc)
            print("Max test aucroc:",max_eval_aucroc)
            word_attn_model.train()
            sent_attn_model.train()
            acc, aucroc = test_accuracy_full_batch(corpus.X_train, corpus.y_train, my_batch, word_attn, sent_attn)
            if acc>max_train_acc:
                max_train_acc = acc
            if aucroc>max_train_aucroc:
                max_train_aucroc = aucroc
            print("Train accuracy:",acc)
            print("Max train accruacy:",max_train_acc)
            print("Train aucroc:",aucroc)
            print("Max train aucroc:",max_train_aucroc)
            #if epoch_counter == 1:
                #break
            g = gen_minibatch(X_train, y_train, mini_batch_size)
            loss_epoch = []
            accuracy_epoch = []
            if epoch_counter==20:
                break
    return loss_full

# %%
loss_full= train_early_stopping(my_batch, corpus.X_train, corpus.y_train, corpus.X_test, corpus.y_test, word_attn, sent_attn, word_optimizer, sent_optimizer, 
                            criterion, 5000, 1, 1)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:182: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:238: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:242: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Loss at 1 minibatches, 0 epoch,(0m 1s) is 0.687592
# Accuracy at 1 minibatches is 0.640625
# Average training loss at this epoch..minibatch..1..is 0.687592
# Validation loss after 1 passes is 0.639866
# Loss at 2 minibatches, 0 epoch,(0m 2s) is 0.649559
# Accuracy at 2 minibatches is 0.750000
# Average training loss at this epoch..minibatch..2..is 0.649559
# Validation loss after 2 passes is 0.621492
# Loss at 3 minibatches, 0 epoch,(0m 3s) is 0.641437
# Accuracy at 3 minibatches is 0.734375
# Average training loss at this epoch..minibatch..3..is 0.641437
# Validation loss after 3 passes is 0.607839
# Loss at 4 minibatches, 0 epoch,(0m 4s) is 0.640008
# Accuracy at 4 minibatches is 0.718750
# Average training loss at this epoch..minibatch..4..is 0.640008
# Validation loss after 4 passes is 0.608844
# Loss at 5 minibatches, 0 epoch,(0m 6s) is 0.631149
# Accuracy at 5 minibatches is 0.718750
# Average training loss at this epoch..minibatch..5..is 0.631149
# Validation loss after 5 passes is 0.591971
# Reached 1 epochs
# i 6
# Test accuracy: 0.7265625
# Max test accruacy: 0.7265625
# Test aucroc: 0.819969278033794
# Max test aucroc: 0.819969278033794
# Train accuracy: 0.73125
# Max train accruacy: 0.73125
# Train aucroc: 0.9264559729676008
# Max train aucroc: 0.9264559729676008
# Loss at 7 minibatches, 1 epoch,(0m 8s) is 0.541312
# Accuracy at 7 minibatches is 0.765625
# Average training loss at this epoch..minibatch..7..is 0.541312
# Validation loss after 7 passes is 0.619467
# Validation loss is higher than training loss at 7 is 0.619467 , stopping training!
# Average training loss at 7 is 0.616176
# Loss at 8 minibatches, 1 epoch,(0m 9s) is 0.510464
# Accuracy at 8 minibatches is 0.789062
# Average training loss at this epoch..minibatch..8..is 0.510464
# Validation loss after 8 passes is 0.669033
# Validation loss is higher than training loss at 8 is 0.669033 , stopping training!
# Average training loss at 8 is 0.596668
# Loss at 9 minibatches, 1 epoch,(0m 10s) is 0.551237
# Accuracy at 9 minibatches is 0.755208
# Average training loss at this epoch..minibatch..9..is 0.551237
# Validation loss after 9 passes is 0.644836
# Validation loss is higher than training loss at 9 is 0.644836 , stopping training!
# Average training loss at 9 is 0.601182
# Loss at 10 minibatches, 1 epoch,(0m 12s) is 0.593048
# Accuracy at 10 minibatches is 0.722656
# Average training loss at this epoch..minibatch..10..is 0.593048
# Validation loss after 10 passes is 0.605010
# Loss at 11 minibatches, 1 epoch,(0m 13s) is 0.583293
# Accuracy at 11 minibatches is 0.728125
# Average training loss at this epoch..minibatch..11..is 0.583293
# Validation loss after 11 passes is 0.551143
# Reached 2 epochs
# i 12
# Test accuracy: 0.71875
# Max test accruacy: 0.7265625
# Test aucroc: 0.8049516908212562
# Max test aucroc: 0.819969278033794
# Train accuracy: 0.728125
# Max train accruacy: 0.73125
# Train aucroc: 0.849440086823541
# Max train aucroc: 0.9264559729676008
# Loss at 13 minibatches, 2 epoch,(0m 15s) is 0.635985
# Accuracy at 13 minibatches is 0.671875
# Average training loss at this epoch..minibatch..13..is 0.635985
# Validation loss after 13 passes is 0.550646
# Loss at 14 minibatches, 2 epoch,(0m 16s) is 0.559656
# Accuracy at 14 minibatches is 0.726562
# Average training loss at this epoch..minibatch..14..is 0.559656
# Validation loss after 14 passes is 0.564080
# Loss at 15 minibatches, 2 epoch,(0m 18s) is 0.546870
# Accuracy at 15 minibatches is 0.729167
# Average training loss at this epoch..minibatch..15..is 0.546870
# Validation loss after 15 passes is 0.548064
# Loss at 16 minibatches, 2 epoch,(0m 19s) is 0.539372
# Accuracy at 16 minibatches is 0.734375
# Average training loss at this epoch..minibatch..16..is 0.539372
# Validation loss after 16 passes is 0.526467
# Loss at 17 minibatches, 2 epoch,(0m 20s) is 0.536318
# Accuracy at 17 minibatches is 0.743750
# Average training loss at this epoch..minibatch..17..is 0.536318
# Validation loss after 17 passes is 0.544362
# Reached 3 epochs
# i 18
# Test accuracy: 0.75
# Max test accruacy: 0.75
# Test aucroc: 0.8605072463768115
# Max test aucroc: 0.8605072463768115
# Train accuracy: 0.746875
# Max train accruacy: 0.746875
# Train aucroc: 0.85351689612015
# Max train aucroc: 0.9264559729676008
# Loss at 19 minibatches, 3 epoch,(0m 23s) is 0.544142
# Accuracy at 19 minibatches is 0.718750
# Average training loss at this epoch..minibatch..19..is 0.544142
# Validation loss after 19 passes is 0.527306
# Loss at 20 minibatches, 3 epoch,(0m 24s) is 0.544554
# Accuracy at 20 minibatches is 0.703125
# Average training loss at this epoch..minibatch..20..is 0.544554
# Validation loss after 20 passes is 0.506359
# Loss at 21 minibatches, 3 epoch,(0m 25s) is 0.528584
# Accuracy at 21 minibatches is 0.734375
# Average training loss at this epoch..minibatch..21..is 0.528584
# Validation loss after 21 passes is 0.504623
# Loss at 22 minibatches, 3 epoch,(0m 26s) is 0.495697
# Accuracy at 22 minibatches is 0.773438
# Average training loss at this epoch..minibatch..22..is 0.495697
# Validation loss after 22 passes is 0.504585
# Loss at 23 minibatches, 3 epoch,(0m 27s) is 0.483641
# Accuracy at 23 minibatches is 0.768750
# Average training loss at this epoch..minibatch..23..is 0.483641
# Validation loss after 23 passes is 0.454900
# Reached 4 epochs
# i 24
# Test accuracy: 0.765625
# Max test accruacy: 0.765625
# Test aucroc: 0.8378378378378378
# Max test aucroc: 0.8605072463768115
# Train accuracy: 0.8
# Max train accruacy: 0.8
# Train aucroc: 0.9185758062162557
# Max train aucroc: 0.9264559729676008
# Loss at 25 minibatches, 4 epoch,(0m 30s) is 0.424729
# Accuracy at 25 minibatches is 0.796875
# Average training loss at this epoch..minibatch..25..is 0.424729
# Validation loss after 25 passes is 0.422421
# Loss at 26 minibatches, 4 epoch,(0m 31s) is 0.412167
# Accuracy at 26 minibatches is 0.796875
# Average training loss at this epoch..minibatch..26..is 0.412167
# Validation loss after 26 passes is 0.383863
# Loss at 27 minibatches, 4 epoch,(0m 32s) is 0.387151
# Accuracy at 27 minibatches is 0.817708
# Average training loss at this epoch..minibatch..27..is 0.387151
# Validation loss after 27 passes is 0.430426
# Loss at 28 minibatches, 4 epoch,(0m 34s) is 0.350048
# Accuracy at 28 minibatches is 0.847656
# Average training loss at this epoch..minibatch..28..is 0.350048
# Validation loss after 28 passes is 0.401394
# Loss at 29 minibatches, 4 epoch,(0m 35s) is 0.358708
# Accuracy at 29 minibatches is 0.846875
# Average training loss at this epoch..minibatch..29..is 0.358708
# Validation loss after 29 passes is 0.415659
# Reached 5 epochs
# i 30
# Test accuracy: 0.828125
# Max test accruacy: 0.828125
# Test aucroc: 0.9180279180279179
# Max test aucroc: 0.9180279180279179
# Train accuracy: 0.909375
# Max train accruacy: 0.909375
# Train aucroc: 0.9616967084639497
# Max train aucroc: 0.9616967084639497
# Loss at 31 minibatches, 5 epoch,(0m 37s) is 0.275271
# Accuracy at 31 minibatches is 0.937500
# Average training loss at this epoch..minibatch..31..is 0.275271
# Validation loss after 31 passes is 0.418217
# Loss at 32 minibatches, 5 epoch,(0m 39s) is 0.280195
# Accuracy at 32 minibatches is 0.929688
# Average training loss at this epoch..minibatch..32..is 0.280195
# Validation loss after 32 passes is 0.407494
# Loss at 33 minibatches, 5 epoch,(0m 40s) is 0.221069
# Accuracy at 33 minibatches is 0.947917
# Average training loss at this epoch..minibatch..33..is 0.221069
# Validation loss after 33 passes is 0.325061
# Loss at 34 minibatches, 5 epoch,(0m 41s) is 0.209942
# Accuracy at 34 minibatches is 0.949219
# Average training loss at this epoch..minibatch..34..is 0.209942
# Validation loss after 34 passes is 0.296772
# Loss at 35 minibatches, 5 epoch,(0m 42s) is 0.190738
# Accuracy at 35 minibatches is 0.959375
# Average training loss at this epoch..minibatch..35..is 0.190738
# Validation loss after 35 passes is 0.312747
# Reached 6 epochs
# i 36
# Test accuracy: 0.859375
# Max test accruacy: 0.859375
# Test aucroc: 0.9349186483103881
# Max test aucroc: 0.9349186483103881
# Train accuracy: 0.953125
# Max train accruacy: 0.953125
# Train aucroc: 0.9928019323671498
# Max train aucroc: 0.9928019323671498
# Loss at 37 minibatches, 6 epoch,(0m 45s) is 0.191960
# Accuracy at 37 minibatches is 0.953125
# Average training loss at this epoch..minibatch..37..is 0.191960
# Validation loss after 37 passes is 0.307254
# Loss at 38 minibatches, 6 epoch,(0m 46s) is 0.136230
# Accuracy at 38 minibatches is 0.960938
# Average training loss at this epoch..minibatch..38..is 0.136230
# Validation loss after 38 passes is 0.255645
# Loss at 39 minibatches, 6 epoch,(0m 47s) is 0.096732
# Accuracy at 39 minibatches is 0.973958
# Average training loss at this epoch..minibatch..39..is 0.096732
# Validation loss after 39 passes is 0.294184
# Loss at 40 minibatches, 6 epoch,(0m 48s) is 0.076102
# Accuracy at 40 minibatches is 0.980469
# Average training loss at this epoch..minibatch..40..is 0.076102
# Validation loss after 40 passes is 0.250435
# Loss at 41 minibatches, 6 epoch,(0m 50s) is 0.063584
# Accuracy at 41 minibatches is 0.984375
# Average training loss at this epoch..minibatch..41..is 0.063584
# Validation loss after 41 passes is 0.266599
# Reached 7 epochs
# i 42
# Test accuracy: 0.890625
# Max test accruacy: 0.890625
# Test aucroc: 0.9585253456221199
# Max test aucroc: 0.9585253456221199
# Train accuracy: 0.996875
# Max train accruacy: 0.996875
# Train aucroc: 0.9963529919861798
# Max train aucroc: 0.9963529919861798
# Loss at 43 minibatches, 7 epoch,(0m 52s) is 0.007279
# Accuracy at 43 minibatches is 1.000000
# Average training loss at this epoch..minibatch..43..is 0.007279
# Validation loss after 43 passes is 0.298029
# Loss at 44 minibatches, 7 epoch,(0m 53s) is 0.006138
# Accuracy at 44 minibatches is 1.000000
# Average training loss at this epoch..minibatch..44..is 0.006138
# Validation loss after 44 passes is 0.303816
# Loss at 45 minibatches, 7 epoch,(0m 54s) is 0.005028
# Accuracy at 45 minibatches is 1.000000
# Average training loss at this epoch..minibatch..45..is 0.005028
# Validation loss after 45 passes is 0.262448
# Loss at 46 minibatches, 7 epoch,(0m 56s) is 0.004256
# Accuracy at 46 minibatches is 1.000000
# Average training loss at this epoch..minibatch..46..is 0.004256
# Validation loss after 46 passes is 0.202124
# Loss at 47 minibatches, 7 epoch,(0m 57s) is 0.019874
# Accuracy at 47 minibatches is 0.996875
# Average training loss at this epoch..minibatch..47..is 0.019874
# Validation loss after 47 passes is 0.223808
# Reached 8 epochs
# i 48
# Test accuracy: 0.9453125
# Max test accruacy: 0.9453125
# Test aucroc: 0.9786159786159786
# Max test aucroc: 0.9786159786159786
# Train accuracy: 0.996875
# Max train accruacy: 0.996875
# Train aucroc: 0.9997600652622487
# Max train aucroc: 0.9997600652622487
# Loss at 49 minibatches, 8 epoch,(0m 59s) is 0.000727
# Accuracy at 49 minibatches is 1.000000
# Average training loss at this epoch..minibatch..49..is 0.000727
# Validation loss after 49 passes is 0.287540
# Loss at 50 minibatches, 8 epoch,(1m 1s) is 0.001401
# Accuracy at 50 minibatches is 1.000000
# Average training loss at this epoch..minibatch..50..is 0.001401
# Validation loss after 50 passes is 0.340507
# Loss at 51 minibatches, 8 epoch,(1m 2s) is 0.001486
# Accuracy at 51 minibatches is 1.000000
# Average training loss at this epoch..minibatch..51..is 0.001486
# Validation loss after 51 passes is 0.334727
# Validation loss is higher than training loss at 51 is 0.334727 , stopping training!
# Average training loss at 51 is 0.333511
# Loss at 52 minibatches, 8 epoch,(1m 3s) is 0.001353
# Accuracy at 52 minibatches is 1.000000
# Average training loss at this epoch..minibatch..52..is 0.001353
# Validation loss after 52 passes is 0.377636
# Validation loss is higher than training loss at 52 is 0.377636 , stopping training!
# Average training loss at 52 is 0.325953
# Loss at 53 minibatches, 8 epoch,(1m 4s) is 0.011950
# Accuracy at 53 minibatches is 0.996875
# Average training loss at this epoch..minibatch..53..is 0.011950
# Validation loss after 53 passes is 0.482154
# Validation loss is higher than training loss at 53 is 0.482154 , stopping training!
# Average training loss at 53 is 0.319917
# Reached 9 epochs
# i 54
# Test accuracy: 0.9375
# Max test accruacy: 0.9453125
# Test aucroc: 0.9621074879227054
# Max test aucroc: 0.9786159786159786
# Train accuracy: 0.996875
# Max train accruacy: 0.996875
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 55 minibatches, 9 epoch,(1m 7s) is 0.000779
# Accuracy at 55 minibatches is 1.000000
# Average training loss at this epoch..minibatch..55..is 0.000779
# Validation loss after 55 passes is 0.465113
# Validation loss is higher than training loss at 55 is 0.465113 , stopping training!
# Average training loss at 55 is 0.312979
# Loss at 56 minibatches, 9 epoch,(1m 8s) is 0.015534
# Accuracy at 56 minibatches is 0.992188
# Average training loss at this epoch..minibatch..56..is 0.015534
# Validation loss after 56 passes is 0.429908
# Validation loss is higher than training loss at 56 is 0.429908 , stopping training!
# Average training loss at 56 is 0.306965
# Loss at 57 minibatches, 9 epoch,(1m 9s) is 0.010650
# Accuracy at 57 minibatches is 0.994792
# Average training loss at this epoch..minibatch..57..is 0.010650
# Validation loss after 57 passes is 0.514519
# Validation loss is higher than training loss at 57 is 0.514519 , stopping training!
# Average training loss at 57 is 0.300588
# Loss at 58 minibatches, 9 epoch,(1m 10s) is 0.009234
# Accuracy at 58 minibatches is 0.996094
# Average training loss at this epoch..minibatch..58..is 0.009234
# Validation loss after 58 passes is 0.506549
# Validation loss is higher than training loss at 58 is 0.506549 , stopping training!
# Average training loss at 58 is 0.294555
# Loss at 59 minibatches, 9 epoch,(1m 12s) is 0.007873
# Accuracy at 59 minibatches is 0.996875
# Average training loss at this epoch..minibatch..59..is 0.007873
# Validation loss after 59 passes is 0.529580
# Validation loss is higher than training loss at 59 is 0.529580 , stopping training!
# Average training loss at 59 is 0.288713
# Reached 10 epochs
# i 60
# Test accuracy: 0.9296875
# Max test accruacy: 0.9453125
# Test aucroc: 0.9730113636363636
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 61 minibatches, 10 epoch,(1m 14s) is 0.006128
# Accuracy at 61 minibatches is 1.000000
# Average training loss at this epoch..minibatch..61..is 0.006128
# Validation loss after 61 passes is 0.496918
# Validation loss is higher than training loss at 61 is 0.496918 , stopping training!
# Average training loss at 61 is 0.283172
# Loss at 62 minibatches, 10 epoch,(1m 15s) is 0.003787
# Accuracy at 62 minibatches is 1.000000
# Average training loss at this epoch..minibatch..62..is 0.003787
# Validation loss after 62 passes is 0.547637
# Validation loss is higher than training loss at 62 is 0.547637 , stopping training!
# Average training loss at 62 is 0.277754
# Loss at 63 minibatches, 10 epoch,(1m 16s) is 0.003860
# Accuracy at 63 minibatches is 1.000000
# Average training loss at this epoch..minibatch..63..is 0.003860
# Validation loss after 63 passes is 0.547211
# Validation loss is higher than training loss at 63 is 0.547211 , stopping training!
# Average training loss at 63 is 0.272589
# Loss at 64 minibatches, 10 epoch,(1m 18s) is 0.003200
# Accuracy at 64 minibatches is 1.000000
# Average training loss at this epoch..minibatch..64..is 0.003200
# Validation loss after 64 passes is 0.457648
# Validation loss is higher than training loss at 64 is 0.457648 , stopping training!
# Average training loss at 64 is 0.267564
# Loss at 65 minibatches, 10 epoch,(1m 19s) is 0.002796
# Accuracy at 65 minibatches is 1.000000
# Average training loss at this epoch..minibatch..65..is 0.002796
# Validation loss after 65 passes is 0.613074
# Validation loss is higher than training loss at 65 is 0.613074 , stopping training!
# Average training loss at 65 is 0.262720
# Reached 11 epochs
# i 66
# Test accuracy: 0.9140625
# Max test accruacy: 0.9453125
# Test aucroc: 0.969180225281602
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 67 minibatches, 11 epoch,(1m 21s) is 0.001000
# Accuracy at 67 minibatches is 1.000000
# Average training loss at this epoch..minibatch..67..is 0.001000
# Validation loss after 67 passes is 0.529982
# Validation loss is higher than training loss at 67 is 0.529982 , stopping training!
# Average training loss at 67 is 0.258047
# Loss at 68 minibatches, 11 epoch,(1m 23s) is 0.001815
# Accuracy at 68 minibatches is 1.000000
# Average training loss at this epoch..minibatch..68..is 0.001815
# Validation loss after 68 passes is 0.617386
# Validation loss is higher than training loss at 68 is 0.617386 , stopping training!
# Average training loss at 68 is 0.253566
# Loss at 69 minibatches, 11 epoch,(1m 24s) is 0.001961
# Accuracy at 69 minibatches is 1.000000
# Average training loss at this epoch..minibatch..69..is 0.001961
# Validation loss after 69 passes is 0.653025
# Validation loss is higher than training loss at 69 is 0.653025 , stopping training!
# Average training loss at 69 is 0.249233
# Loss at 70 minibatches, 11 epoch,(1m 25s) is 0.001644
# Accuracy at 70 minibatches is 1.000000
# Average training loss at this epoch..minibatch..70..is 0.001644
# Validation loss after 70 passes is 0.647335
# Validation loss is higher than training loss at 70 is 0.647335 , stopping training!
# Average training loss at 70 is 0.245020
# Loss at 71 minibatches, 11 epoch,(1m 26s) is 0.001523
# Accuracy at 71 minibatches is 1.000000
# Average training loss at this epoch..minibatch..71..is 0.001523
# Validation loss after 71 passes is 0.494526
# Validation loss is higher than training loss at 71 is 0.494526 , stopping training!
# Average training loss at 71 is 0.240954
# Reached 12 epochs
# i 72
# Test accuracy: 0.8984375
# Max test accruacy: 0.9453125
# Test aucroc: 0.9704106280193237
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 73 minibatches, 12 epoch,(1m 29s) is 0.001099
# Accuracy at 73 minibatches is 1.000000
# Average training loss at this epoch..minibatch..73..is 0.001099
# Validation loss after 73 passes is 0.614190
# Validation loss is higher than training loss at 73 is 0.614190 , stopping training!
# Average training loss at 73 is 0.237022
# Loss at 74 minibatches, 12 epoch,(1m 30s) is 0.001154
# Accuracy at 74 minibatches is 1.000000
# Average training loss at this epoch..minibatch..74..is 0.001154
# Validation loss after 74 passes is 0.571882
# Validation loss is higher than training loss at 74 is 0.571882 , stopping training!
# Average training loss at 74 is 0.233218
# Loss at 75 minibatches, 12 epoch,(1m 31s) is 0.001169
# Accuracy at 75 minibatches is 1.000000
# Average training loss at this epoch..minibatch..75..is 0.001169
# Validation loss after 75 passes is 0.646165
# Validation loss is higher than training loss at 75 is 0.646165 , stopping training!
# Average training loss at 75 is 0.229535
# Loss at 76 minibatches, 12 epoch,(1m 33s) is 0.001028
# Accuracy at 76 minibatches is 1.000000
# Average training loss at this epoch..minibatch..76..is 0.001028
# Validation loss after 76 passes is 0.633819
# Validation loss is higher than training loss at 76 is 0.633819 , stopping training!
# Average training loss at 76 is 0.225958
# Loss at 77 minibatches, 12 epoch,(1m 34s) is 0.000930
# Accuracy at 77 minibatches is 1.000000
# Average training loss at this epoch..minibatch..77..is 0.000930
# Validation loss after 77 passes is 0.558452
# Validation loss is higher than training loss at 77 is 0.558452 , stopping training!
# Average training loss at 77 is 0.222490
# Reached 13 epochs
# i 78
# Test accuracy: 0.90625
# Max test accruacy: 0.9453125
# Test aucroc: 0.9722304722304722
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 79 minibatches, 13 epoch,(1m 36s) is 0.000348
# Accuracy at 79 minibatches is 1.000000
# Average training loss at this epoch..minibatch..79..is 0.000348
# Validation loss after 79 passes is 0.681451
# Validation loss is higher than training loss at 79 is 0.681451 , stopping training!
# Average training loss at 79 is 0.219125
# Loss at 80 minibatches, 13 epoch,(1m 37s) is 0.000373
# Accuracy at 80 minibatches is 1.000000
# Average training loss at this epoch..minibatch..80..is 0.000373
# Validation loss after 80 passes is 0.399369
# Validation loss is higher than training loss at 80 is 0.399369 , stopping training!
# Average training loss at 80 is 0.215860
# Loss at 81 minibatches, 13 epoch,(1m 39s) is 0.000366
# Accuracy at 81 minibatches is 1.000000
# Average training loss at this epoch..minibatch..81..is 0.000366
# Validation loss after 81 passes is 0.692224
# Validation loss is higher than training loss at 81 is 0.692224 , stopping training!
# Average training loss at 81 is 0.212691
# Loss at 82 minibatches, 13 epoch,(1m 40s) is 0.000455
# Accuracy at 82 minibatches is 1.000000
# Average training loss at this epoch..minibatch..82..is 0.000455
# Validation loss after 82 passes is 0.582148
# Validation loss is higher than training loss at 82 is 0.582148 , stopping training!
# Average training loss at 82 is 0.209619
# Loss at 83 minibatches, 13 epoch,(1m 41s) is 0.000460
# Accuracy at 83 minibatches is 1.000000
# Average training loss at this epoch..minibatch..83..is 0.000460
# Validation loss after 83 passes is 0.574038
# Validation loss is higher than training loss at 83 is 0.574038 , stopping training!
# Average training loss at 83 is 0.206631
# Reached 14 epochs
# i 84
# Test accuracy: 0.90625
# Max test accruacy: 0.9453125
# Test aucroc: 0.9672811059907833
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 85 minibatches, 14 epoch,(1m 43s) is 0.000428
# Accuracy at 85 minibatches is 1.000000
# Average training loss at this epoch..minibatch..85..is 0.000428
# Validation loss after 85 passes is 0.647987
# Validation loss is higher than training loss at 85 is 0.647987 , stopping training!
# Average training loss at 85 is 0.203727
# Loss at 86 minibatches, 14 epoch,(1m 45s) is 0.000376
# Accuracy at 86 minibatches is 1.000000
# Average training loss at this epoch..minibatch..86..is 0.000376
# Validation loss after 86 passes is 0.628689
# Validation loss is higher than training loss at 86 is 0.628689 , stopping training!
# Average training loss at 86 is 0.200902
# Loss at 87 minibatches, 14 epoch,(1m 46s) is 0.000319
# Accuracy at 87 minibatches is 1.000000
# Average training loss at this epoch..minibatch..87..is 0.000319
# Validation loss after 87 passes is 0.479804
# Validation loss is higher than training loss at 87 is 0.479804 , stopping training!
# Average training loss at 87 is 0.198153
# Loss at 88 minibatches, 14 epoch,(1m 47s) is 0.000306
# Accuracy at 88 minibatches is 1.000000
# Average training loss at this epoch..minibatch..88..is 0.000306
# Validation loss after 88 passes is 0.429340
# Validation loss is higher than training loss at 88 is 0.429340 , stopping training!
# Average training loss at 88 is 0.195478
# Loss at 89 minibatches, 14 epoch,(1m 48s) is 0.000293
# Accuracy at 89 minibatches is 1.000000
# Average training loss at this epoch..minibatch..89..is 0.000293
# Validation loss after 89 passes is 0.596318
# Validation loss is higher than training loss at 89 is 0.596318 , stopping training!
# Average training loss at 89 is 0.192875
# Reached 15 epochs
# i 90
# Test accuracy: 0.9609375
# Max test accruacy: 0.9609375
# Test aucroc: 0.9734254992319508
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 91 minibatches, 15 epoch,(1m 51s) is 0.000301
# Accuracy at 91 minibatches is 1.000000
# Average training loss at this epoch..minibatch..91..is 0.000301
# Validation loss after 91 passes is 0.680472
# Validation loss is higher than training loss at 91 is 0.680472 , stopping training!
# Average training loss at 91 is 0.190341
# Loss at 92 minibatches, 15 epoch,(1m 52s) is 0.000252
# Accuracy at 92 minibatches is 1.000000
# Average training loss at this epoch..minibatch..92..is 0.000252
# Validation loss after 92 passes is 0.596455
# Validation loss is higher than training loss at 92 is 0.596455 , stopping training!
# Average training loss at 92 is 0.187872
# Loss at 93 minibatches, 15 epoch,(1m 53s) is 0.000220
# Accuracy at 93 minibatches is 1.000000
# Average training loss at this epoch..minibatch..93..is 0.000220
# Validation loss after 93 passes is 0.553141
# Validation loss is higher than training loss at 93 is 0.553141 , stopping training!
# Average training loss at 93 is 0.185465
# Loss at 94 minibatches, 15 epoch,(1m 54s) is 0.000213
# Accuracy at 94 minibatches is 1.000000
# Average training loss at this epoch..minibatch..94..is 0.000213
# Validation loss after 94 passes is 0.574896
# Validation loss is higher than training loss at 94 is 0.574896 , stopping training!
# Average training loss at 94 is 0.183120
# Loss at 95 minibatches, 15 epoch,(1m 56s) is 0.000204
# Accuracy at 95 minibatches is 1.000000
# Average training loss at this epoch..minibatch..95..is 0.000204
# Validation loss after 95 passes is 0.678474
# Validation loss is higher than training loss at 95 is 0.678474 , stopping training!
# Average training loss at 95 is 0.180833
# Reached 16 epochs
# i 96
# Test accuracy: 0.9296875
# Max test accruacy: 0.9609375
# Test aucroc: 0.9679951690821256
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 97 minibatches, 16 epoch,(1m 58s) is 0.000216
# Accuracy at 97 minibatches is 1.000000
# Average training loss at this epoch..minibatch..97..is 0.000216
# Validation loss after 97 passes is 0.670605
# Validation loss is higher than training loss at 97 is 0.670605 , stopping training!
# Average training loss at 97 is 0.178603
# Loss at 98 minibatches, 16 epoch,(1m 59s) is 0.000189
# Accuracy at 98 minibatches is 1.000000
# Average training loss at this epoch..minibatch..98..is 0.000189
# Validation loss after 98 passes is 0.466173
# Validation loss is higher than training loss at 98 is 0.466173 , stopping training!
# Average training loss at 98 is 0.176427
# Loss at 99 minibatches, 16 epoch,(2m 1s) is 0.000186
# Accuracy at 99 minibatches is 1.000000
# Average training loss at this epoch..minibatch..99..is 0.000186
# Validation loss after 99 passes is 0.534261
# Validation loss is higher than training loss at 99 is 0.534261 , stopping training!
# Average training loss at 99 is 0.174304
# Loss at 100 minibatches, 16 epoch,(2m 2s) is 0.000179
# Accuracy at 100 minibatches is 1.000000
# Average training loss at this epoch..minibatch..100..is 0.000179
# Validation loss after 100 passes is 0.566844
# Validation loss is higher than training loss at 100 is 0.566844 , stopping training!
# Average training loss at 100 is 0.172231
# Loss at 101 minibatches, 16 epoch,(2m 3s) is 0.000162
# Accuracy at 101 minibatches is 1.000000
# Average training loss at this epoch..minibatch..101..is 0.000162
# Validation loss after 101 passes is 0.662050
# Validation loss is higher than training loss at 101 is 0.662050 , stopping training!
# Average training loss at 101 is 0.170206
# Reached 17 epochs
# i 102
# Test accuracy: 0.9296875
# Max test accruacy: 0.9609375
# Test aucroc: 0.9612016908212561
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 103 minibatches, 17 epoch,(2m 6s) is 0.000169
# Accuracy at 103 minibatches is 1.000000
# Average training loss at this epoch..minibatch..103..is 0.000169
# Validation loss after 103 passes is 0.384903
# Validation loss is higher than training loss at 103 is 0.384903 , stopping training!
# Average training loss at 103 is 0.168228
# Loss at 104 minibatches, 17 epoch,(2m 7s) is 0.000169
# Accuracy at 104 minibatches is 1.000000
# Average training loss at this epoch..minibatch..104..is 0.000169
# Validation loss after 104 passes is 0.638384
# Validation loss is higher than training loss at 104 is 0.638384 , stopping training!
# Average training loss at 104 is 0.166297
# Loss at 105 minibatches, 17 epoch,(2m 8s) is 0.000167
# Accuracy at 105 minibatches is 1.000000
# Average training loss at this epoch..minibatch..105..is 0.000167
# Validation loss after 105 passes is 0.536476
# Validation loss is higher than training loss at 105 is 0.536476 , stopping training!
# Average training loss at 105 is 0.164409
# Loss at 106 minibatches, 17 epoch,(2m 9s) is 0.000154
# Accuracy at 106 minibatches is 1.000000
# Average training loss at this epoch..minibatch..106..is 0.000154
# Validation loss after 106 passes is 0.560067
# Validation loss is higher than training loss at 106 is 0.560067 , stopping training!
# Average training loss at 106 is 0.162563
# Loss at 107 minibatches, 17 epoch,(2m 10s) is 0.000141
# Accuracy at 107 minibatches is 1.000000
# Average training loss at this epoch..minibatch..107..is 0.000141
# Validation loss after 107 passes is 0.707134
# Validation loss is higher than training loss at 107 is 0.707134 , stopping training!
# Average training loss at 107 is 0.160757
# Reached 18 epochs
# i 108
# Test accuracy: 0.9296875
# Max test accruacy: 0.9609375
# Test aucroc: 0.9702999702999704
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 109 minibatches, 18 epoch,(2m 13s) is 0.000093
# Accuracy at 109 minibatches is 1.000000
# Average training loss at this epoch..minibatch..109..is 0.000093
# Validation loss after 109 passes is 0.454942
# Validation loss is higher than training loss at 109 is 0.454942 , stopping training!
# Average training loss at 109 is 0.158992
# Loss at 110 minibatches, 18 epoch,(2m 14s) is 0.000114
# Accuracy at 110 minibatches is 1.000000
# Average training loss at this epoch..minibatch..110..is 0.000114
# Validation loss after 110 passes is 0.535591
# Validation loss is higher than training loss at 110 is 0.535591 , stopping training!
# Average training loss at 110 is 0.157265
# Loss at 111 minibatches, 18 epoch,(2m 15s) is 0.000120
# Accuracy at 111 minibatches is 1.000000
# Average training loss at this epoch..minibatch..111..is 0.000120
# Validation loss after 111 passes is 0.403324
# Validation loss is higher than training loss at 111 is 0.403324 , stopping training!
# Average training loss at 111 is 0.155576
# Loss at 112 minibatches, 18 epoch,(2m 17s) is 0.000122
# Accuracy at 112 minibatches is 1.000000
# Average training loss at this epoch..minibatch..112..is 0.000122
# Validation loss after 112 passes is 0.634313
# Validation loss is higher than training loss at 112 is 0.634313 , stopping training!
# Average training loss at 112 is 0.153922
# Loss at 113 minibatches, 18 epoch,(2m 18s) is 0.000116
# Accuracy at 113 minibatches is 1.000000
# Average training loss at this epoch..minibatch..113..is 0.000116
# Validation loss after 113 passes is 0.420607
# Validation loss is higher than training loss at 113 is 0.420607 , stopping training!
# Average training loss at 113 is 0.152303
# Reached 19 epochs
# i 114
# Test accuracy: 0.953125
# Max test accruacy: 0.9609375
# Test aucroc: 0.9722304722304722
# Max test aucroc: 0.9786159786159786
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0
# Loss at 115 minibatches, 19 epoch,(2m 20s) is 0.000096
# Accuracy at 115 minibatches is 1.000000
# Average training loss at this epoch..minibatch..115..is 0.000096
# Validation loss after 115 passes is 0.576863
# Validation loss is higher than training loss at 115 is 0.576863 , stopping training!
# Average training loss at 115 is 0.150717
# Loss at 116 minibatches, 19 epoch,(2m 22s) is 0.000109
# Accuracy at 116 minibatches is 1.000000
# Average training loss at this epoch..minibatch..116..is 0.000109
# Validation loss after 116 passes is 0.343527
# Validation loss is higher than training loss at 116 is 0.343527 , stopping training!
# Average training loss at 116 is 0.149165
# Loss at 117 minibatches, 19 epoch,(2m 23s) is 0.000098
# Accuracy at 117 minibatches is 1.000000
# Average training loss at this epoch..minibatch..117..is 0.000098
# Validation loss after 117 passes is 0.645707
# Validation loss is higher than training loss at 117 is 0.645707 , stopping training!
# Average training loss at 117 is 0.147643
# Loss at 118 minibatches, 19 epoch,(2m 24s) is 0.000099
# Accuracy at 118 minibatches is 1.000000
# Average training loss at this epoch..minibatch..118..is 0.000099
# Validation loss after 118 passes is 0.537826
# Validation loss is higher than training loss at 118 is 0.537826 , stopping training!
# Average training loss at 118 is 0.146153
# Loss at 119 minibatches, 19 epoch,(2m 25s) is 0.000095
# Accuracy at 119 minibatches is 1.000000
# Average training loss at this epoch..minibatch..119..is 0.000095
# Validation loss after 119 passes is 0.508079
# Validation loss is higher than training loss at 119 is 0.508079 , stopping training!
# Average training loss at 119 is 0.144692
# Reached 20 epochs
# i 120
# Test accuracy: 0.9609375
# Max test accruacy: 0.9609375
# Test aucroc: 0.9842105263157894
# Max test aucroc: 0.9842105263157894
# Train accuracy: 1.0
# Max train accruacy: 1.0
# Train aucroc: 1.0
# Max train aucroc: 1.0

# %%
#print(test_accuracy_full_batch(corpus.X_test, corpus.y_test, my_batch, word_attn, sent_attn))

# %%
#test_accuracy_full_batch(corpus.X_train, corpus.y_train, my_batch, word_attn, sent_attn)
